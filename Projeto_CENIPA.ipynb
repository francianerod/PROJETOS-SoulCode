# %% [markdown]
# <a href="https://colab.research.google.com/github/francianerod/PROJETOS-SoulCode/blob/main/Projeto_CENIPA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PYTHON PARA ANÁLISE DE DADOS**
#
# Escola: SoulCode Academy
#
# Curso: Bootcamp Analista de Dados - Martech - AD2
#
# Período: Semana 6 - ETL
#
# Professor: Franciane Rodrigues

# %% [markdown]
# # **CONCEITOS**

# %% [markdown]
# ![Foto 1.png](data:image/png;base64,...)

# %% [markdown]
# *  Dados Estruturados:
# São dados formatados segundo parâmetros específicos, para organização em esquemas relacionais. Um dos principais formatos de dados estruturados são as tabelas, que os distribuem em linhas e colunas com valores pré-determinados. Exemplos: planilhas eletrônicas e bancos de dados (arquivos do Excel, CSV, SQL, entre outros)
#
# *  Dados Semiestruturados: Como o nome indica, são dados com alguma organização interna, mas que não são inteiramente estruturados.
# Exemplos: arquivos da web (HTML, XML, OWL, entre outros).
#
# *  Dados Não Estruturados: São dados sem uma organização ou hierarquia interna clara. É a categoria mais ampla, abrangendo a maior parte dos dados na web.
# Exemplos: documentos de texto (arquivos do Word, PDFs), arquivos de mídia (imagem, áudio e vídeo), e-mails, mensagens de texto, dados de redes sociais, dispositivos móveis, Internet das Coisas (IoT), entre outros.

# %% [markdown]
# ![foto 2.png](data:image/png;base64,...)

# %% [markdown]
# ![foto 3.png](data:image/png;base64,...)

# %% [markdown]
# ![foto 4.png](data:image/png;base64,...)

# %% [markdown]
# **DataFrame:**
# Um DataFrame é uma estrutura de dados tabular bidimensional, semelhante a uma planilha ou tabela de banco de dados. É uma estrutura de dados flexível que organiza os dados em colunas rotuladas e permite a manipulação eficiente desses dados. Os DataFrames são amplamente usados em bibliotecas de análise de dados, como o pandas em Python, para realizar operações como filtragem, transformação e análise de dados.
#
# **Dataset:**
# Um dataset (conjunto de dados) é um termo mais amplo que se refere a uma coleção de dados. Pode ser um conjunto de dados estruturado, como um DataFrame, ou pode ser uma coleção de dados não estruturados ou semiestruturados, como texto, imagens, áudio, vídeos, etc. Um dataset pode conter um ou mais DataFrames, juntamente com outros tipos de dados.

# %% [markdown]
# ![foto 5.png](data:image/png;base64,...)

# %% [markdown]
# ETL: Como funciona o processo?
# *  Extração (E): nesta fase, os dados são coletados de diferentes sistemas
# organizacionais e conduzidos a um espaço temporário (staging area - durante a execução da ETL em andamento), onde são convertidos em um mesmo formato para transformação.
# *  Transformação (T): os dados brutos são lapidados e padronizados conforme as necessidades da empresa. Ao fim desta etapa, os dados estão “limpos”, estruturados e prontos para armazenamento.
# *  Carregamento (L): os dados tratados são enviados a um repositório específico, onde serão armazenados em segurança e acionados para consulta interna.

# %% [markdown]
# A biblioteca Pandas é uma biblioteca Python para análise de dados. Seu nome é derivado do termo “dados de painel” (panel data), um termo econométrico utilizado para se referir a conjuntos de dados estruturados multidimensionais. Ela possui código aberto e uso gratuito.
#
# O Pandas é construído com base em duas bibliotecas mais famosas do Python: matplotlib, para visualização de dados, e NumPy para operações matemáticas. O Pandas é uma união dessas bibliotecas, permitindo que você acesse muitos dos métodos de matplotlib e NumPy com menos código.
#
# A biblioteca Pandas é conhecida por sua alta produtividade e alto desempenho. Ela é bastante popular porque torna a importação e a análise de dados muito mais fácil.
#
# Pandas: https://pandas.pydata.org/docs/getting_started/index.html

# %% [markdown]
# ## **Fontes de Pesquisa**
#
# *  Documentação
# *  Blogs
# *  Vídeos
# *  Livros
# *  Stackoverflow
# *  ChatGPT
# *  Github
# *  Kaggle

# %% [markdown]
# ## **Informações gerais da base de dados**
#
# A base de dados de ocorrências aeronáuticas é gerenciada pelo Centro de Investigação e Prevenção de Acidentes Aeronáuticos (CENIPA). Constam nesta base de dados as ocorrências aeronáuticas notificadas ao CENIPA no anos de 2010 a 2021 que ocorreram em solo brasileiro.
#
# Dentre as informações disponíveis estão os dados sobre as aeronaves envolvidas, fatalidades, local, data, horário dos eventos e informações taxonômicas típicas das investigações de acidentes (AIG). São resguardadas a privacidade de pessoas físicas/jurídicas envolvidas conforme previsto pela Lei de Acesso à Informação (Lei n° 12.527, de 18 de novembro de 2011).
#
# Essa base de dados é composta por informações preliminares provenientes do formulário CENIPA-05 (Ficha de Notificação de Ocorrências Aeronáuticas) e consolidada a partir dos relatórios de investigações publicados. Outra forma de visualização desses dados é pelo [__*Painel SIPAER*__](https://painelsipaer.cenipa.fab.mil.br/QvAJAXZfc/opendoc.htm?document=SIGAER%2Fgia%2Fqvw%2Fpainel_sipaer.qvw&host=QVS%40cirros31-37&anonymous=true) disponível na página do CENIPA.
#
# Dados proveniente dos Programas de Gerenciamento de Prevenção administrados pelo CENIPA (Emissão de Raio Laser e Risco Baloeiro) não constam nesta base. Esses programas possuem formulários próprios para coleta de dados com foco exclusivo para gerenciamento do risco, enquanto os dados coletados pelo formulário CENIPA-05 têm foco principal na investigação de acidentes (AIG).

# %% [markdown]
# **Sobre os dados**
#
# Opcional: Fazer o dicionário de dados do CENIPA
#
# Fonte: https://dados.gov.br/dados/conjuntos-dados/ocorrencias-aeronauticas-da-aviacao-civil-brasileira

# %% [markdown]
# ## **Instalação de Pacotes**

# %% [markdown]
# *  **gcsfs:** É uma biblioteca Python que permite interagir com o Google Cloud Storage (GCS), um serviço de armazenamento de objetos do Google Cloud Platform. Com o gcsfs, você pode ler e gravar arquivos no GCS diretamente do seu código Python.
#
# *  **pandera:** É uma biblioteca Python para validação de dados. Ela facilita a especificação e aplicação de regras de validação a estruturas de dados, como DataFrames do pandas. O pandera ajuda a verificar se os dados estão em conformidade com essas regras, identificando problemas de qualidade dos dados.

# %% [markdown]
# Obs: Ao adicionar o ponto de exclamação antes de um comando em uma célula do Colab, você está indicando ao ambiente que deseja executar esse comando no shell do sistema subjacente.
#
# O uso do ponto de exclamação no Colab é uma convenção específica desse ambiente para permitir a execução de comandos do sistema operacional diretamente no notebook, facilitando a instalação de pacotes e a execução de outras tarefas relacionadas ao sistema.

# %%
# Executar uma vez
#!pip install gcsfs
#!pip install pandera

# %% [markdown]
# ## **Abertura de Bibliotecas**

# %%
# Abertura de bibliotecas
import os                           # Importar a biblioteca "os" para interagir com o sistema operacional
import pandas as pd                 # Importar a biblioteca "pandas" e atribuir um apelido "pd"
import numpy as np                  # O numpy é uma biblioteca popular para computação numérica em Python, fornecendo suporte para matrizes multidimensionais, funções matemáticas avançadas e manipulação eficiente de dados numéricos
import pandera as pa                # O pandera é uma biblioteca que adiciona recursos de validação de dados ao pandas, permitindo a definição de esquemas e regras para verificar a qualidade e integridade dos dados.
from google.cloud import storage    # Esse módulo fornece funcionalidades para interagir com o serviço de armazenamento em nuvem do Google Cloud Platform (GCP)

# %%
# Ignorar avisos
import warnings
warnings.filterwarnings("ignore")

# %%
# Configuração da quantidade de colunas para aparecer em um Datraframe
pd.set_option('display.max_columns',100)

# %% [markdown]
# # **EXTRAÇÃO**

# %% [markdown]
# *  Google Drive
# *  Google Cloud
# *  MongoDB - vamos ver na semana 8.
# *   **Tipos de separador:** Vírgula (,) - Ponto e vírgula (;) - Tabulação (\t) - Espaço em branco ( )
# *   **Enconding:** UTF-8, ISO-8859-1, UTF-16, UTF-32, ASCII

# %% [markdown]
# ### **Google Drive**

# %%
# Comando de abertura para Google Drive
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# Extração por Google Drive
#df = pd.read_csv('/content/drive/MyDrive/Semana 6 - Python para Análise de Dados/cenipa_bruto.csv',
#                 sep=';',
#                 encoding='ISO-8859-1',
#                 dayfirst = True)

# %% [markdown]
# ### **Google Cloud**
#
# *   Documentação: https://cloud.google.com/docs/authentication?hl=pt-br

# %%
# CONFIGURANDO DA CHAVE DE SEGURANCA - ACESSO O PROJETO
serviceAccount = '/content/X509-cert-5781360384442289393.pem'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# %%
# Configurações Google Cloud Storage - ACESSO AO BUCKET
client = storage.Client()
bucket = client.get_bucket('projetos-aula')                         # nome da bucket
bucket.blob('cenipa_bruto.csv')                                     # nome do arquivo
path = 'gs://projetos-aula/projeto-cenipa/bruto/cenipa_bruto.csv'   # gsutil

# %%
# Abertura da base de dados e cópia de segurança (bucket)
df = pd.read_csv(path,
                 sep=';',
                 encoding='ISO-8859-1',
                 dayfirst = True)
dfback = df.copy()

# %% [markdown]
# ## **Pré-Análise**

# %%
# Visualização do dataframe
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 81027               81027               81027
# 1                 81030               81030               81030
# 2                 81023               81023               81023
# 3                 81029               81029               81029
# 4                 81025               81025               81025
# ...                 ...                 ...                 ...
# 6764              40324               40324               40324
# 6765              39527               39527               39527
# 6766              40211               40211               40211
# 6767              40349               40349               40349
# 6768              40351               40351               40351
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  81027               81027          INCIDENTE GRAVE
# 1                  81030               81030                INCIDENTE
# 2                  81023               81023          INCIDENTE GRAVE
# 3                  81029               81029                INCIDENTE
# 4                  81025               81025                INCIDENTE
# ...                  ...                 ...                      ...
# 6764               40324               40324                INCIDENTE
# 6765               39527               39527                 ACIDENTE
# 6766               40211               40211                INCIDENTE
# 6767               40349               40349                INCIDENTE
# 6768               40351               40351                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    NaN                  NaN           SÃO PAULO
# 1                    NaN                  NaN             VITÓRIA
# 2                    NaN                  NaN           AMERICANA
# 3                    NaN                  NaN      BELO HORIZONTE
# 4                    NaN                  NaN              MANAUS
# ...                  ...                  ...                 ...
# 6764                 NaN                  NaN             PELOTAS
# 6765      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 6766                 ***                  ***      RIO DE JANEIRO
# 6767                 NaN                  NaN               BELÉM
# 6768                 NaN                  NaN      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia  \
# 0               SP          BRASIL                 SBSP     09/10/2022
# 1               ES          BRASIL                 SBVT     09/10/2022
# 2               SP          BRASIL                 SDAI     06/10/2022
# 3               MG          BRASIL                 SBBH     06/10/2022
# 4               AM          BRASIL                 SBEG     05/10/2022
# ...            ...             ...                  ...            ...
# 6764            RS          BRASIL                 SBPK     05/01/2010
# 6765            MT          BRASIL                  ***     04/01/2010
# 6766            RJ          BRASIL                  ***     03/01/2010
# 6767            PA          BRASIL                 SBBE     03/01/2010
# 6768            RJ          BRASIL                 SBRJ     03/01/2010
#
#      ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0           16:30:00                            SIM               ATIVA
# 1           16:20:00                            SIM               ATIVA
# 2           15:30:00                            SIM          FINALIZADA
# 3           00:44:00                            SIM          FINALIZADA
# 4           20:56:00                            SIM          FINALIZADA
# ...              ...                            ...                 ...
# 6764        19:25:00                            SIM          FINALIZADA
# 6765        17:30:00                            SIM          FINALIZADA
# 6766        12:00:00                            SIM          FINALIZADA
# 6767        11:05:00                            SIM          FINALIZADA
# 6768        03:00:00                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                      A DEFINIR                            NÃO
# 1                      A DEFINIR                            NÃO
# 2                            ***                            NÃO
# 3                            ***                            NÃO
# 4                            ***                            NÃO
# ...                          ...                            ...
# 6764                         NaN                            NÃO
# 6765           A-539/CENIPA/2018                            SIM
# 6766                         ***                            NÃO
# 6767                         NaN                            NÃO
# 6768                         NaN                            NÃO
#
#      divulgacao_dia_publicacao  total_recomendacoes  \
# 0                          NaN                    0
# 1                          NaN                    0
# 2                          NaN                    0
# 3                          NaN                    0
# 4                          NaN                    0
# ...                        ...                  ...
# 6764                       NaN                    0
# 6765                2019-10-28                    0
# 6766                       NaN                    0
# 6767                       NaN                    0
# 6768                       NaN                    0
#
#       total_aeronaves_envolvidas ocorrencia_saida_pista
# 0                              1                    SIM
# 1                              1                    NÃO
# 2                              1                    SIM
# 3                              1                    NÃO
# 4                              1                    NÃO
# ...                          ...                    ...
# 6764                           1                    NÃO
# 6765                           1                    NÃO
# 6766                           1                    NÃO
# 6767                           1                    NÃO
# 6768                           1                    NÃO
#
# [6769 rows x 22 columns]

# %%
# Visualização dos dados começando pelo cabeçalho
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              81027               81027               81027
# 1              81030               81030               81030
# 2              81023               81023               81023
# 3              81029               81029               81029
# 4              81025               81025               81025
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               81027               81027          INCIDENTE GRAVE
# 1               81030               81030                INCIDENTE
# 2               81023               81023          INCIDENTE GRAVE
# 3               81029               81029                INCIDENTE
# 4               81025               81025                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN         SÃO PAULO            SP
# 1                 NaN                  NaN           VITÓRIA            ES
# 2                 NaN                  NaN         AMERICANA            SP
# 3                 NaN                  NaN    BELO HORIZONTE            MG
# 4                 NaN                  NaN            MANAUS            AM
#
#   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0          BRASIL                 SBSP     09/10/2022        16:30:00
# 1          BRASIL                 SBVT     09/10/2022        16:20:00
# 2          BRASIL                 SDAI     06/10/2022        15:30:00
# 3          BRASIL                 SBBH     06/10/2022        00:44:00
# 4          BRASIL                 SBEG     05/10/2022        20:56:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            SIM               ATIVA
# 1                            SIM               ATIVA
# 2                            SIM          FINALIZADA
# 3                            SIM          FINALIZADA
# 4                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                   A DEFINIR                            NÃO
# 1                   A DEFINIR                            NÃO
# 2                         ***                            NÃO
# 3                         ***                            NÃO
# 4                         ***                            NÃO
#
#   divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  \
# 0                       NaN                    0                           1
# 1                       NaN                    0                           1
# 2                       NaN                    0                           1
# 3                       NaN                    0                           1
# 4                       NaN                    0                           1
#
#   ocorrencia_saida_pista
# 0                    SIM
# 1                    NÃO
# 2                    SIM
# 3                    NÃO
# 4                    NÃO

# %%
# Visualização do df começando pelo final
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 6764              40324               40324               40324
# 6765              39527               39527               39527
# 6766              40211               40211               40211
# 6767              40349               40349               40349
# 6768              40351               40351               40351
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 6764               40324               40324                INCIDENTE
# 6765               39527               39527                 ACIDENTE
# 6766               40211               40211                INCIDENTE
# 6767               40349               40349                INCIDENTE
# 6768               40351               40351                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 6764                 NaN                  NaN             PELOTAS
# 6765      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 6766                 ***                  ***      RIO DE JANEIRO
# 6767                 NaN                  NaN               BELÉM
# 6768                 NaN                  NaN      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia  \
# 6764            RS          BRASIL                 SBPK     05/01/2010
# 6765            MT          BRASIL                  ***     04/01/2010
# 6766            RJ          BRASIL                  ***     03/01/2010
# 6767            PA          BRASIL                 SBBE     03/01/2010
# 6768            RJ          BRASIL                 SBRJ     03/01/2010
#
#      ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 6764        19:25:00                            SIM          FINALIZADA
# 6765        17:30:00                            SIM          FINALIZADA
# 6766        12:00:00                            SIM          FINALIZADA
# 6767        11:05:00                            SIM          FINALIZADA
# 6768        03:00:00                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 6764                         NaN                            NÃO
# 6765           A-539/CENIPA/2018                            SIM
# 6766                         ***                            NÃO
# 6767                         NaN                            NÃO
# 6768                         NaN                            NÃO
#
#      divulgacao_dia_publicacao  total_recomendacoes  \
# 6764                       NaN                    0
# 6765                2019-10-28                    0
# 6766                       NaN                    0
# 6767                       NaN                    0
# 6768                       NaN                    0
#
#       total_aeronaves_envolvidas ocorrencia_saida_pista
# 6764                           1                    NÃO
# 6765                           1                    NÃO
# 6766                           1                    NÃO
# 6767                           1                    NÃO
# 6768                           1                    NÃO

# %%
# Visualização do df de forma aleatória
# sample() é um método da biblioteca Pandas em Python que é usado para retornar uma amostra aleatória de linhas de um DataFrame

df.sample(5)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 4959              46854               46854               46854
# 2937              66050               66050               66050
# 2032              78372               78372               78372
# 5927              44652               44652               44652
# 3094              65358               65358               65358
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 4959               46854               46854                 ACIDENTE
# 2937               66050               66050          INCIDENTE GRAVE
# 2032               78372               78372                 ACIDENTE
# 5927               44652               44652          INCIDENTE GRAVE
# 3094               65358               65358                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude      ocorrencia_cidade  \
# 4959      -23.4363888889       -46.7319444444              SÃO PAULO
# 2937      -23.2288888889       -45.8711111111    SÃO JOSÉ DOS CAMPOS
# 2032     -48.480.555.556               -69.78  SÃO PAULO DE OLIVENÇA
# 5927                 ***                  ***          NOVO HAMBURGO
# 3094        3.7766666667        38.5322222222              FORTALEZA
#
#      ocorrencia_uf ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia  \
# 4959            SP          BRASIL                  ***     21/01/2013
# 2937            SP          BRASIL                 SBSJ     28/11/2016
# 2032            AM          BRASIL                  ***     17/12/2018
# 5927            RS          BRASIL                 SSNH     19/06/2011
# 3094            CE          BRASIL                 SBFZ     28/06/2016
#
#      ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 4959        14:48:00                            ***          FINALIZADA
# 2937        16:07:00                            SIM          FINALIZADA
# 2032        21:00:00                            SIM          FINALIZADA
# 5927        13:00:00                            ***          FINALIZADA
# 3094        17:00:00                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 4959           A-010/CENIPA/2013                            SIM
# 2937          IG-153/CENIPA/2016                            NÃO
# 2032           A-189/CENIPA/2018                            SIM
# 5927                   A DEFINIR                            SIM
# 3094                         ***                            NÃO
#
#      divulgacao_dia_publicacao  total_recomendacoes  \
# 4959                2014-05-26                    1
# 2937                       NaN                    0
# 2032                2020-04-22                    2
# 5927                2018-12-04                    5
# 3094                       NaN                    0
#
#       total_aeronaves_envolvidas ocorrencia_saida_pista
# 4959                           1                    NÃO
# 2937                           1                    SIM
# 2032                           1                    NÃO
# 5927                           1                    SIM
# 3094                           1                    NÃO

# %%
# Tamanho do df
df.shape
# Out:
# (6769, 22)

# %%
# Verificar o tipo de dado em cada coluna
df.dtypes
# Out:
# codigo_ocorrencia                  int64
# codigo_ocorrencia1                 int64
# codigo_ocorrencia2                 int64
# codigo_ocorrencia3                 int64
# codigo_ocorrencia4                 int64
# ocorrencia_classificacao          object
# ocorrencia_latitude               object
# ocorrencia_longitude              object
# ocorrencia_cidade                 object
# ocorrencia_uf                     object
# ocorrencia_pais                   object
# ocorrencia_aerodromo              object
# ocorrencia_dia                    object
# ocorrencia_hora                   object
# investigacao_aeronave_liberada    object
# investigacao_status               object
# divulgacao_relatorio_numero       object
# divulgacao_relatorio_publicado    object
# divulgacao_dia_publicacao         object
# total_recomendacoes                int64
# total_aeronaves_envolvidas         int64
# ocorrencia_saida_pista            object
# dtype: object

# %%
# Contar a quantidade de observações
df.count()
# Out:
# codigo_ocorrencia                 6769
# codigo_ocorrencia1                6769
# codigo_ocorrencia2                6769
# codigo_ocorrencia3                6769
# codigo_ocorrencia4                6769
# ocorrencia_classificacao          6769
# ocorrencia_latitude               5135
# ocorrencia_longitude              5135
# ocorrencia_cidade                 6769
# ocorrencia_uf                     6769
# ocorrencia_pais                   6769
# ocorrencia_aerodromo              6769
# ocorrencia_dia                    6769
# ocorrencia_hora                   6767
# investigacao_aeronave_liberada    6531
# investigacao_status               6428
# divulgacao_relatorio_numero       5987
# divulgacao_relatorio_publicado    6769
# divulgacao_dia_publicacao         1781
# total_recomendacoes               6769
# total_aeronaves_envolvidas        6769
# ocorrencia_saida_pista            6769
# dtype: int64

# %%
# Informações detalhadas do DF
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6769 entries, 0 to 6768
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   codigo_ocorrencia               6769 non-null   int64
#  1   codigo_ocorrencia1              6769 non-null   int64
#  2   codigo_ocorrencia2              6769 non-null   int64
#  3   codigo_ocorrencia3              6769 non-null   int64
#  4   codigo_ocorrencia4              6769 non-null   int64
#  5   ocorrencia_classificacao        6769 non-null   object
#  6   ocorrencia_latitude             5135 non-null   object
#  7   ocorrencia_longitude            5135 non-null   object
#  8   ocorrencia_cidade               6769 non-null   object
#  9   ocorrencia_uf                   6769 non-null   object
#  10  ocorrencia_pais                 6769 non-null   object
#  11  ocorrencia_aerodromo            6769 non-null   object
#  12  ocorrencia_dia                  6769 non-null   object
#  13  ocorrencia_hora                 6767 non-null   object
#  14  investigacao_aeronave_liberada  6531 non-null   object
#  15  investigacao_status             6428 non-null   object
#  16  divulgacao_relatorio_numero     5987 non-null   object
#  17  divulgacao_relatorio_publicado  6769 non-null   object
#  18  divulgacao_dia_publicacao       1781 non-null   object
#  19  total_recomendacoes             6769 non-null   int64
#  20  total_aeronaves_envolvidas      6769 non-null   int64
#  21  ocorrencia_saida_pista          6769 non-null   object
# dtypes: int64(7), object(15)
# memory usage: 1.1+ MB

# %%
# Backup local do df
dfback1 = df.copy()

# %% [markdown]
# # **TRANSFORMAÇÃO**

# %% [markdown]
# **Verificações gerais e básicas de qualquer base de dados, se houver os casos abaixo:**
#
# *  Escolher as possíveis colunas importantes para a análise;
# *  Verificar se há colunas iguais;
# *  Verificação e tratamento de valores (ou observações) únicos;
# *  Verificação e tratamento de duplicadas
# *  Verificação e tratamento de inconsistência
# *  Verificação e tratamento de valores nulos
# *  Tradução/Renomeação
# *  Transformação de tipos adequados dos dados
# *  Garantia de qualidade e integridade dos dados

# %%
# Visualização do df de forma aleatória:
df.sample(5)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 2648              67054               67054               67054
# 2476              77245               77245               77245
# 5697              51795               51795               51795
# 3590              53263               53263               53263
# 1065              79750               79750               79750
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 2648               67054               67054                 ACIDENTE
# 2476               77245               77245                INCIDENTE
# 5697               51795               51795                INCIDENTE
# 3590               53263               53263                 ACIDENTE
# 1065               79750               79750                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 2648      -19.8427777778       -44.6011111111     PARÁ DE MINAS            MG
# 2476     -235.066.666.66      -466.338.888.88         SÃO PAULO            SP
# 5697                 ***                  ***      CAMPO GRANDE            MS
# 3590      -16.6280555556       -49.3455555556           GOIÂNIA            GO
# 1065          -16.625556           -49.349444           GOIÂNIA            GO
#
#      ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 2648          BRASIL                 SNPA     24/07/2017        19:00:00
# 2476          BRASIL                 SBMT     10/12/2017        11:52:00
# 5697          BRASIL                 SBCG     23/11/2011        20:02:00
# 3590          BRASIL                 SBNV     08/05/2015        11:00:00
# 1065          BRASIL                 SBNV     01/12/2020        11:30:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 2648                            SIM                 NaN
# 2476                            SIM          FINALIZADA
# 5697                            ***          FINALIZADA
# 3590                            SIM          FINALIZADA
# 1065                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 2648                         NaN                            NÃO
# 2476                         ***                            NÃO
# 5697                         ***                            NÃO
# 3590           A-069/CENIPA/2015                            SIM
# 1065                         ***                            NÃO
#
#      divulgacao_dia_publicacao  total_recomendacoes  \
# 2648                       NaN                    0
# 2476                       NaN                    0
# 5697                       NaN                    0
# 3590                2016-04-22                    0
# 1065                       NaN                    0
#
#       total_aeronaves_envolvidas ocorrencia_saida_pista
# 2648                           1                    NÃO
# 2476                           1                    NÃO
# 5697                           1                    NÃO
# 3590                           1                    NÃO
# 1065                           1                    NÃO

# %%
# Modo 1: Verificando se as colunas são iguais
if (df['codigo_ocorrencia'] == df['codigo_ocorrencia4']).all():
    print("As colunas são iguais.")
else:
    print("As colunas são diferentes.")
# Out:
# As colunas são iguais.

# %%
# Modo 2: Verificando se as colunas são iguais
# Nome das colunas a serem verificadas
colunas_verificar = ['codigo_ocorrencia1', 'codigo_ocorrencia2', 'codigo_ocorrencia3', 'codigo_ocorrencia4']

# Verificando se as colunas são iguais à coluna 'codigo_ocorrencia'
for coluna in colunas_verificar:
    if (df['codigo_ocorrencia']== df[coluna]).all():
        print(f"A coluna {coluna} é igual à coluna 'codigo_ocorrencia'.")
    else:
        print(f"A coluna {coluna} é diferente da coluna 'codigo_ocorrencia'.")
# Out:
# A coluna codigo_ocorrencia1 é igual à coluna 'codigo_ocorrencia'.
# A coluna codigo_ocorrencia2 é igual à coluna 'codigo_ocorrencia'.
# A coluna codigo_ocorrencia3 é igual à coluna 'codigo_ocorrencia'.
# A coluna codigo_ocorrencia4 é igual à coluna 'codigo_ocorrencia'.

# %%
# Verifica se dados são unicos na coluna
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
# Retirada de colunas identicas (codigo_ocorrencia1 , codigo_ocorrencia2,codigo_ocorrencia3 , codigo_ocorrencia4)
# O parâmetro axis=1 indica que as colunas devem ser removidas (em oposição a linhas, que seria axis=0).
# O parâmetro inplace=True indica que a operação deve ser feita diretamente no DataFrame df, ou seja, o DataFrame será alterado permanentemente

df.drop(['codigo_ocorrencia1',
         'codigo_ocorrencia2',
         'codigo_ocorrencia3',
         'codigo_ocorrencia4'],axis=1, inplace=True)

# %%
# Verificar dados Nulos , ausentes , etc - isnull()
df.isna().sum()
# Out:
# codigo_ocorrencia                    0
# ocorrencia_classificacao             0
# ocorrencia_latitude               1634
# ocorrencia_longitude              1634
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo                 0
# ocorrencia_dia                       0
# ocorrencia_hora                      2
# investigacao_aeronave_liberada     238
# investigacao_status                341
# divulgacao_relatorio_numero        782
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4988
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %%
# Calcular a porcentagem de valores nulos em cada coluna
porcentagem_nulos = (df.isnull().sum() / len(df)) * 100

# Exibir a porcentagem de valores nulos em cada coluna
print(round(porcentagem_nulos,1))
# Out:
# codigo_ocorrencia                  0.0
# ocorrencia_classificacao           0.0
# ocorrencia_latitude               24.1
# ocorrencia_longitude              24.1
# ocorrencia_cidade                  0.0
# ocorrencia_uf                      0.0
# ocorrencia_pais                    0.0
# ocorrencia_aerodromo               0.0
# ocorrencia_dia                     0.0
# ocorrencia_hora                    0.0
# investigacao_aeronave_liberada     3.5
# investigacao_status                5.0
# divulgacao_relatorio_numero       11.6
# divulgacao_relatorio_publicado     0.0
# divulgacao_dia_publicacao         73.7
# total_recomendacoes                0.0
# total_aeronaves_envolvidas         0.0
# ocorrencia_saida_pista             0.0
# dtype: float64

# %%
# Verificação de valores unicos na coluna
print(pd.unique(df['ocorrencia_pais']))
# Out:
# ['BRASIL']

# %%
# Verificação de valores unicos na coluna
print(pd.unique(df['total_recomendacoes']))
# Out:
# [ 0  1  2  3  4  5  7  6  8  9 12 13 11 20 23 10 19]

# %%
# Verificação de valores unicos na coluna
print(pd.unique(df['investigacao_status']))
# Out:
# ['ATIVA' 'FINALIZADA' nan]

# %%
# Retirada de colunas com problemas e/ou não utilizadas na analise
df.drop(['ocorrencia_latitude',
         'ocorrencia_longitude',
         'ocorrencia_pais',
         'investigacao_aeronave_liberada',
         'investigacao_status',
         'divulgacao_relatorio_numero',
         'divulgacao_relatorio_publicado',
         'divulgacao_dia_publicacao',
         'total_recomendacoes'],axis=1,inplace=True)

# %%
# Calcular a porcentagem de valores nulos em cada coluna
porcentagem_nulos = (df.isnull().sum() / len(df)) * 100

# Exibir a porcentagem de valores nulos em cada coluna
print(round(porcentagem_nulos,1))
# Out:
# codigo_ocorrencia             0.0
# ocorrencia_classificacao      0.0
# ocorrencia_cidade             0.0
# ocorrencia_uf                 0.0
# ocorrencia_aerodromo          0.0
# ocorrencia_dia                0.0
# ocorrencia_hora               0.0
# total_aeronaves_envolvidas    0.0
# ocorrencia_saida_pista        0.0
# dtype: float64

# %%
# Checando dados Nulos , ausentes , etc
df.isnull().sum()
# Out:
# codigo_ocorrencia             0
# ocorrencia_classificacao      0
# ocorrencia_cidade             0
# ocorrencia_uf                 0
# ocorrencia_aerodromo          0
# ocorrencia_dia                0
# ocorrencia_hora               2
# total_aeronaves_envolvidas    0
# ocorrencia_saida_pista        0
# dtype: int64

# %% [markdown]
# *  **Comentário:** Verificação de dados inconsistentes um a um, utilize os comandos sorted() e unique() conforme abaixo. Anote as inconsistências ou informações fora do padrão. Aqui no caso eu já sei que os valores inconsistentes estão nessas colunas após verificação coluna a coluna.

# %%
# Visualiza valores unicos para ver inconsistências. Utilize a função sorted() para ordenação
print(sorted(pd.unique(df['ocorrencia_classificacao'])))
# Out:
# ['ACIDENTE', 'INCIDENTE', 'INCIDENTE GRAVE']

# %%
# Visualiza valores unicos para ver inconsistências. Utilize a função sorted() para ordenação
print(sorted(pd.unique(df['ocorrencia_cidade'])))
# Out:
# ['ABADIA DE GOIÁS', 'ACARÁ', 'ACREÚNA', 'AFONSO CLÁUDIO', 'AFUÁ', 'AGUAÍ', 'AGUDO', 'AGUDOS', 'AIMORÉS', 'ALAGOINHAS', 'ALCÂNTARA', 'ALEGRETE', 'ALFENAS', 'ALFREDO CHAVES', 'ALIANÇA DO TOCANTINS', 'ALMEIRIM', 'ALMIRANTE TAMANDARÉ', 'ALTA FLORESTA', "ALTA FLORESTA D'OESTE", 'ALTAIR', 'ALTAMIRA', 'ALTO ALEGRE', 'ALTO ARAGUAIA', 'ALTO GARÇAS', 'ALTO HORIZONTE', 'ALTO PARAGUAI', 'ALTO PARANÁ', 'ALTO PARAÍSO DE GOIÁS', 'ALTO PARNAÍBA', 'ALTO PIQUIRI', 'ALTÔNIA', 'AMAJARI', 'AMAPORÃ', 'AMAPÁ', 'AMARGOSA', 'AMERICANA', 'ANAJÁS', 'ANAMÃ', 'ANANINDEUA', 'ANAPU', 'ANAURILÂNDIA', 'ANDARAÍ', 'ANDRADINA', 'ANGRA DOS REIS', 'ANGÉLICA', 'ANTONINA', 'ANÁPOLIS', 'APUÍ', 'AQUIDAUANA', 'AQUIRAZ', 'ARACAJU', 'ARACATI', 'ARACATU', 'ARACRUZ', 'ARAGARÇAS', 'ARAGUAIANA', 'ARAGUARI', 'ARAGUAÍNA', 'ARAL MOREIRA', 'ARAMBARÉ', 'ARANDU', 'ARAPIRACA', 'ARAPONGAS', 'ARAPOTI', 'ARAPUTANGA', 'ARAQUARI', 'ARARAQUARA', 'ARARAS', 'ARARI', 'ARARUAMA', 'ARAUCÁRIA', 'ARAXÁ', 'ARAÇATUBA', 'ARAÇU', 'AREALVA', 'ARENÁPOLIS', 'ARIPUANÃ', 'ARIQUEMES', 'ARRAIAL DO CABO', 'ARROIO GRANDE', 'ARTUR NOGUEIRA', 'ARUANÃ', 'ARÊS', 'ASSIS', 'ASSIS BRASIL', 'ASSIS CHATEAUBRIAND', 'ASSUNÇÃO DO PIAUÍ', 'ATALAIA DO NORTE', 'ATIBAIA', 'AURIFLAMA', 'AUTAZES', 'AVANHANDAVA', 'AVARÉ', 'BACABAL', 'BAEPENDI', 'BAGÉ', 'BAIXA GRANDE DO RIBEIRO', 'BAIXO GUANDU', 'BALNEÁRIO CAMBORIÚ', 'BALSA NOVA', 'BALSAS', 'BANANEIRAS', 'BANDEIRANTES', 'BANNACH', 'BARBACENA', 'BARCARENA', 'BARCELOS', 'BARRA BONITA', 'BARRA DE SÃO FRANCISCO', 'BARRA DO BUGRES', 'BARRA DO CHOÇA', 'BARRA DO GARÇAS', 'BARRA DO PIRAÍ', 'BARRA DO RIBEIRO', 'BARRA VELHA', 'BARREIRAS', 'BARREIRINHAS', 'BARREIROS', 'BARRETOS', 'BARRO ALTO', 'BARRO DURO', 'BARÃO', 'BARÃO DE MELGAÇO', 'BATATAIS', 'BATAYPORÃ', 'BAURU', 'BAYEUX', 'BEBEDOURO', 'BEBERIBE', 'BELA VISTA DO PARAÍSO', 'BELMONTE', 'BELO HORIZONTE', 'BELTERRA', 'BELÉM', 'BENEVIDES', 'BENTO GONÇALVES', 'BERTIOGA', 'BIRIGUI', 'BIRITIBA-MIRIM', 'BLUMENAU', 'BOA ESPERANÇA', 'BOA ESPERANÇA DO SUL', 'BOA VIAGEM', 'BOA VISTA', 'BOA VISTA DA APARECIDA', 'BOA VISTA DO RAMOS', 'BOA VISTA DO TUPIM', 'BOCA DO ACRE', 'BOCAINA', 'BODOQUENA', 'BOITUVA', 'BOM DESPACHO', 'BOM JESUS', 'BOM JESUS DE GOIÁS', 'BOM JESUS DO AMPARO', 'BOM JESUS DO GALHO', 'BOM JESUS DOS PERDÕES', 'BOM RETIRO', 'BONFIM', 'BONITO', 'BOQUIRA', 'BOTUCATU', 'BRAGANÇA', 'BRAGANÇA PAULISTA', 'BRASILÂNDIA', 'BRASILÂNDIA DE MINAS', 'BRASNORTE', 'BRASÍLIA', 'BREJINHO DE NAZARÉ', 'BREU BRANCO', 'BREVES', 'BROTAS', 'BRUSQUE', 'BUENO BRANDÃO', 'BURITAMA', 'BURITI ALEGRE', 'BURITIS', 'CAARAPÓ', 'CABECEIRA GRANDE', 'CABECEIRAS', 'CABEDELO', 'CABO FRIO', 'CABREÚVA', 'CABROBÓ', 'CACEQUI', 'CACHOEIRA DO ARARI', 'CACHOEIRA DO SUL', 'CACHOEIRA DOURADA', 'CACHOEIRO DE ITAPEMIRIM', 'CACOAL', 'CAFELÂNDIA', 'CAFEZAL DO SUL', 'CAIABU', 'CAIAPÔNIA', 'CAICÓ', 'CAIEIRAS', 'CAIRU', 'CAJAMAR', 'CAJATI', 'CAJOBI', 'CALDAS NOVAS', 'CAMANDUCAIA', 'CAMAPUÃ', 'CAMAQUÃ', 'CAMARAGIBE', 'CAMAÇARI', 'CAMBARÁ', 'CAMBÉ', 'CAMETÁ', 'CAMOCIM', 'CAMPINA GRANDE', 'CAMPINA GRANDE DO SUL', 'CAMPINA VERDE', 'CAMPINAS', 'CAMPINAS DO PIAUÍ', 'CAMPINAS DO SUL', 'CAMPINORTE', 'CAMPINÁPOLIS', 'CAMPO BELO', 'CAMPO BONITO', 'CAMPO DO TENENTE', 'CAMPO FLORIDO', 'CAMPO GRANDE', 'CAMPO LARGO', 'CAMPO LIMPO DE GOIÁS', 'CAMPO MAGRO', 'CAMPO MOURÃO', 'CAMPO NOVO DO PARECIS', 'CAMPO VERDE', 'CAMPOS DO JORDÃO', 'CAMPOS DOS GOYTACAZES', 'CAMPOS LINDOS', 'CANARANA', 'CANDEIAS DO JAMARI', 'CANDÓI', 'CANELA', 'CANOAS', 'CANTAGALO', 'CANTÁ', 'CANUTAMA', 'CAPITÓLIO', 'CAPIVARI', 'CAPÃO DA CANOA', 'CARACARAÍ', 'CARACOL', 'CARAGUATATUBA', 'CARAPICUÍBA', 'CARATINGA', 'CARAUARI', 'CARAVELAS', 'CARAZINHO', 'CARIDADE', 'CARLOS CHAGAS', 'CARMO DO CAJURU', 'CAROEBE', 'CAROLINA', 'CARUARU', 'CASA BRANCA', 'CASCAVEL', 'CASIMIRO DE ABREU', 'CASSILÂNDIA', 'CASTANHEIRA', 'CASTELO', 'CASTRO', 'CATALÃO', 'CATANDUVA', 'CATAS ALTAS', 'CATUTI', 'CAUCAIA', 'CAXIAS DO SUL', 'CAÇAPAVA', 'CAÇAPAVA DO SUL', 'CAÇU', 'CEARÁ-MIRIM', 'CEREJEIRAS', 'CERES', 'CHAPADA', 'CHAPADA DOS GUIMARÃES', 'CHAPADA GAÚCHA', 'CH ...

# %%
# Visualiza valores unicos para ver inconsistências. Utilize a função sorted() para ordenação
print(sorted(pd.unique(df['ocorrencia_uf'])))
# Out:
# ['***', 'AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC', 'SE', 'SP', 'TO']

# %%
# Visualiza valores unicos para ver inconsistências. Utilize a função sorted() para ordenação
print(sorted(pd.unique(df['ocorrencia_aerodromo'])))
# Out:
# ['***', '**NI', '5JTI', '9PAA', '9PBS', '9PFC', '9PFX', '9PHD', '9PSD', 'APUA', 'SBAE', 'SBAN', 'SBAQ', 'SBAR', 'SBAT', 'SBAU', 'SBAX', 'SBBE', 'SBBH', 'SBBI', 'SBBP', 'SBBQ', 'SBBR', 'SBBU', 'SBBV', 'SBBW', 'SBBZ', 'SBCA', 'SBCB', 'SBCF', 'SBCG', 'SBCH', 'SBCJ', 'SBCP', 'SBCR', 'SBCT', 'SBCX', 'SBCY', 'SBCZ', 'SBDN', 'SBEG', 'SBEK', 'SBFE', 'SBFI', 'SBFL', 'SBFN', 'SBFS', 'SBFZ', 'SBGL', 'SBGO', 'SBGP', 'SBGR', 'SBGV', 'SBGW', 'SBHT', 'SBIH', 'SBIL', 'SBIP', 'SBIT', 'SBIZ', 'SBJA', 'SBJC', 'SBJD', 'SBJF', 'SBJH', 'SBJI', 'SBJP', 'SBJR', 'SBJU', 'SBJV', 'SBKG', 'SBKP', 'SBLE', 'SBLJ', 'SBLO', 'SBMA', 'SBMD', 'SBME', 'SBMG', 'SBMK', 'SBML', 'SBMO', 'SBMQ', 'SBMS', 'SBMT', 'SBMY', 'SBNF', 'SBNM', 'SBNT', 'SBNV', 'SBPA', 'SBPB', 'SBPC', 'SBPF', 'SBPG', 'SBPJ', 'SBPK', 'SBPL', 'SBPN', 'SBPO', 'SBPP', 'SBPR', 'SBPS', 'SBPV', 'SBQV', 'SBRB', 'SBRD', 'SBRF', 'SBRJ', 'SBRP', 'SBSC', 'SBSG', 'SBSI', 'SBSJ', 'SBSL', 'SBSM', 'SBSN', 'SBSP', 'SBSR', 'SBST', 'SBSV', 'SBTA', 'SBTD', 'SBTE', 'SBTF', 'SBTG', 'SBTK', 'SBTR', 'SBTT', 'SBTV', 'SBUA', 'SBUF', 'SBUL', 'SBUR', 'SBUY', 'SBVG', 'SBVH', 'SBVT', 'SBZM', 'SD4V', 'SD6Y', 'SDAA', 'SDAE', 'SDAG', 'SDAI', 'SDAM', 'SDBA', 'SDBB', 'SDBK', 'SDBN', 'SDBV', 'SDCD', 'SDCO', 'SDDN', 'SDDQ', 'SDDR', 'SDED', 'SDEE', 'SDEH', 'SDEM', 'SDEN', 'SDET', 'SDFD', 'SDGR', 'SDGX', 'SDHP', 'SDHU', 'SDIG', 'SDIH', 'SDIM', 'SDIO', 'SDIP', 'SDJA', 'SDJB', 'SDJC', 'SDJL', 'SDJO', 'SDKE', 'SDKH', 'SDLL', 'SDLO', 'SDLP', 'SDLY', 'SDLZ', 'SDMC', 'SDMH', 'SDMJ', 'SDMM', 'SDMV', 'SDNB', 'SDNE', 'SDNH', 'SDNI', 'SDOI', 'SDOR', 'SDOW', 'SDPA', 'SDPG', 'SDPN', 'SDPW', 'SDPY', 'SDQG', 'SDRC', 'SDRE', 'SDRK', 'SDRS', 'SDRV', 'SDSC', 'SDTB', 'SDTF', 'SDTI', 'SDTK', 'SDTO', 'SDUB', 'SDUL', 'SDVE', 'SDVG', 'SDVH', 'SDVI', 'SDVK', 'SDVL', 'SDVO', 'SDWC', 'SDWU', 'SDWV', 'SDXF', 'SDYF', 'SDYJ', 'SDYW', 'SDZS', 'SDZX', 'SIAN', 'SIBH', 'SIBK', 'SIBO', 'SIBX', 'SIEK', 'SIFC', 'SIFH', 'SIFQ', 'SIFV', 'SIFW', 'SIJG', 'SIJY', 'SIKC', 'SILC', 'SILQ', 'SILT', 'SIMB', 'SIMQ', 'SING', 'SION', 'SIPB', 'SIPO', 'SIPU', 'SIPY', 'SIQE', 'SIQH', 'SIQK', 'SIRI', 'SIRS', 'SISN', 'SISY', 'SIUD', 'SIVB', 'SIVQ', 'SIVU', 'SIXD', 'SIXE', 'SIZM', 'SJAH', 'SJBH', 'SJBM', 'SJBX', 'SJBY', 'SJCY', 'SJDU', 'SJEH', 'SJFM', 'SJFU', 'SJGL', 'SJHG', 'SJHR', 'SJIF', 'SJIJ', 'SJLJ', 'SJLO', 'SJLU', 'SJLY', 'SJNC', 'SJNP', 'SJNQ', 'SJOD', 'SJOG', 'SJPT', 'SJQN', 'SJRG', 'SJTO', 'SJVL', 'SJVO', 'SJVX', 'SJWQ', 'SJXM', 'SJYG', 'SJYR', 'SNAG', 'SNAL', 'SNAS', 'SNAU', 'SNAX', 'SNAZ', 'SNBA', 'SNBG', 'SNBO', 'SNBR', 'SNBS', 'SNCJ', 'SNCL', 'SNCP', 'SNCT', 'SNCV', 'SNCW', 'SNCX', 'SNDC', 'SNDH', 'SNDP', 'SNDR', 'SNDT', 'SNDU', 'SNDV', 'SNEJ', 'SNEM', 'SNFE', 'SNFJ', 'SNFS', 'SNFX', 'SNGA', 'SNGG', 'SNGQ', 'SNGS', 'SNGU', 'SNGV', 'SNGW', 'SNGX', 'SNHB', 'SNHE', 'SNHH', 'SNHS', 'SNIG', 'SNIT', 'SNIZ', 'SNJD', 'SNJI', 'SNJK', 'SNJL', 'SNJN', 'SNJO', 'SNJR', 'SNKB', 'SNKE', 'SNKF', 'SNKH', 'SNKI', 'SNKK', 'SNLF', 'SNLM', 'SNLO', 'SNMA', 'SNMD', 'SNME', 'SNMH', 'SNMU', 'SNMX', 'SNNL', 'SNOD', 'SNOF', 'SNOG', 'SNPA', 'SNPC', 'SNPD', 'SNPJ', 'SNPO', 'SNPX', 'SNPY', 'SNQV', 'SNQX', 'SNRP', 'SNRU', 'SNSG', 'SNSH', 'SNSW', 'SNTF', 'SNTO', 'SNTY', 'SNUN', 'SNUZ', 'SNVB', 'SNVC', 'SNVR', 'SNVS', 'SNWC', 'SNWS', 'SNXI', 'SNXR', 'SNXT', 'SNXW', 'SNYE', 'SNYP', 'SNYR', 'SNYS', 'SNZA', 'SSAC', 'SSAK', 'SSAQ', 'SSAU', 'SSAY', 'SSBG', 'SSBL', 'SSBN', 'SSBR', 'SSCD', 'SSCE', 'SSCF', 'SSCK', 'SSCL', 'SSCN', 'SSCP', 'SSCR', 'SSCT', 'SSDK', 'SSDO', 'SSDP', 'SSER', 'SSFB', 'SSFC', 'SSFE', 'SSGA', 'SSGB', 'SSGG', 'SSGP', 'SSGX', 'SSHS', 'SSIE', 'SSIJ', 'SSIQ', 'SSJA', 'SSJI', 'SSJL', 'SSKG', 'SSKK', 'SSKM', 'SSKS', 'SSKT', 'SSKW', 'SSKZ', 'SSLT', 'SSMH', 'SSMK', 'SSMW', 'SSNB', 'SSNG', 'SSNH', 'SSNV', 'SSOG', 'SSOK', 'SSOL', 'SSOS', 'SSOT', 'SSPB', 'SSPG', 'SSPI', 'SSPL', 'SSPO', 'SSPQ', 'SSPS', 'SSPV', 'SSPX', 'SSQI', 'SSQT', 'SSQZ', 'SSRA', 'SSRS', 'SSRZ', 'SSSB', 'SSSC', 'SSSE', 'SSSS', 'SSSZ', 'SSTH', 'SSTL', 'SSUB', 'SSUL', 'SSUV', 'SSVA', 'SSVN', 'SSWF', 'SSXO', 'SSZL', 'SSZR', 'SWAQ',  ...

# %%
# Visualiza valores unicos para ver inconsistências. Utilize a função sorted() para ordenação
print(sorted(pd.unique(df['total_aeronaves_envolvidas'])))
# Out:
# [1, 2, 3]

# %%
# Visualiza valores unicos para ver inconsistências. Utilize a função sorted() para ordenação
print(sorted(pd.unique(df['ocorrencia_saida_pista'])))
# Out:
# ['NÃO', 'SIM']

# %% [markdown]
# **Qual a diferença entre pd.NA e pd.NaN e quando usar?**
#
# Tanto pd.NA quanto pd.NaN são usados para representar valores ausentes ou nulos em pandas, mas eles são usados em diferentes situações.
#
# *  pd.NA é usado para representar valores ausentes em dados que não sejam numéricos, como dados categóricos ou de texto.
#
# *  pd.NaN é usado para representar valores ausentes em dados numéricos, como colunas que contêm números reais ou inteiros
#
# Em geral, você deve usar pd.NA para colunas que contêm dados não numéricos, como categorias ou strings, e pd.NaN para colunas que contêm dados numéricos, como floats ou inteiros. Isso ajuda a evitar confusão e inconsistência nos seus dados e cálculos.
#
# No entanto, vale lembrar que há casos em que pode haver sobreposição entre dados numéricos e não numéricos, por exemplo, quando uma coluna contém valores mistos de string e float. Nesses casos, a escolha entre pd.NA e pd.NaN dependerá do tipo de dado predominante na coluna e do objetivo da análise.

# %%
# Correção de inconsistência
df.replace(['***', '**NI'],pd.NA,inplace=True)
df.replace(pd.NA, np.NaN, inplace=True)        # Transformação de pd.NA para np.NaN (recomendado)

# %%
# Visualiza valores unicos para ver inconsistências
print(pd.unique(df['ocorrencia_aerodromo']))
print('-----------------------------------')
print(pd.unique(df['ocorrencia_uf']))
# Out:
# ['SBSP' 'SBVT' 'SDAI' 'SBBH' 'SBEG' nan 'SBNV' 'SBUL' 'SBAU' 'SBBP' 'SBTE'
#  'SBGR' 'SBMT' 'SBCT' 'SBCF' 'SIEK' 'SBRJ' 'SDLP' 'SWPD' 'SBMA' 'SNYP'
#  'SNHH' 'SBJF' 'SBCY' 'SBPS' 'SBMK' 'SBNF' 'SBTF' 'SSMK' 'SNAX' 'SBKP'
#  'SBFZ' 'SNPA' 'SBIZ' 'SNFX' 'SDRK' 'SBRF' 'SSBN' 'SBPR' 'SBSJ' 'SBST'
#  'SBGO' 'SDCO' 'SBSV' 'SBPJ' 'SBGL' 'SBRD' 'SBBE' 'SBCH' 'SBLO' 'SBPL'
#  'SWGW' 'SWLB' 'SBBU' 'SBMQ' 'SIPO' 'SIAN' 'SBJV' 'SNDC' 'SBBI' 'SBSC'
#  'SSKG' 'SBBR' 'SSBG' 'SBIL' 'SBPO' 'SDAM' 'SSOG' 'SBPV' 'SBSR' 'SBBV'
#  'SBSN' 'SBFI' 'SDFD' 'SJEH' 'SBSI' 'SWFN' 'SDIG' 'SNHS' 'SBJP' 'SBPA'
#  'SBJA' 'SBJR' 'SBRP' 'SISN' 'SBMO' 'SNRU' 'SNQV' 'SNCP' 'SDIH' 'SBTG'
#  'SIVU' 'SWMV' 'SIRI' 'SNIT' 'SBRB' 'SSPI' 'SWCA' 'SBJI' 'SBFL' 'SDRC'
#  'SNMH' 'SNBS' 'SWLW' 'SSOT' 'SNPO' 'SBCG' 'SBJD' 'SDEN' 'APUA' 'SDAG'
#  'SIUD' 'SDBB' 'SBMS' 'SDDR' 'SDVH' 'SSKK' 'SJVX' 'SBVH' 'SDRV' 'SBML'
#  'SSGP' 'SD6Y' 'SNJL' 'SDZS' 'SIBK' 'SNDV' 'SBJH' 'SBCZ' 'SSNH' 'SBMG'
#  'SSZR' 'SDAE' 'SSOL' 'SIFQ' 'SSWF' 'SBPP' 'SBAX' 'SJLJ' 'SDPW' 'SSFB'
#  'SBSG' 'SDTB' 'SSCE' 'SSBL' 'SNCT' 'SILQ' 'SSQZ' 'SILT' 'SBIH' 'SIFW'
#  'SBDN' 'SWHP' 'SNGW' 'SBPG' 'SJOG' 'SJPT' 'SWPI' 'SWNG' 'SSKT' 'SJNC'
#  'SBEK' 'SWON' 'SIZM' 'SWME' 'SJOD' 'SBCB' 'SDVG' 'SSPO' 'SBCR' 'SBCX'
#  'SSCD' 'SIXE' 'SNLM' 'SDIP' 'SBTV' 'SWNH' 'SSCL' 'SJBX' 'SNGA' 'SIMQ'
#  'SIQE' 'SWXV' 'SWXQ' '9PBS' 'SISY' 'SDLL' 'SNCJ' 'SBGP' 'SDUL' 'SIVB'
#  'SWNS' 'SDRS' 'SSNG' 'SBZM' 'SSRA' 'SWLC' 'SWTS' 'SWEN' 'SBNM' 'SBAT'
#  'SBMD' 'SJIJ' 'SBSL' 'SDAA' 'SBCP' 'SWRW' 'SWVW' 'SJYG' 'SBVG' 'SJGL'
#  'SSFE' 'SSIE' 'SJLY' 'SWEK' 'SSCK' 'SBGV' 'SNDT' 'SIMB' 'SNRP' 'SSXO'
#  'SSUL' '9PAA' 'SDCD' 'SNAS' 'SWEJ' 'SIFC' 'SSDK' 'SBJC' 'SBTT' 'SSKZ'
#  'SBCA' 'SWPY' 'SSOK' 'SDYJ' 'SWFR' '9PSD' 'SNAL' 'SDOI' 'SBGW' 'SDJA'
#  'SSSC' 'SWGI' 'SNPC' 'SDEM' 'SJIF' 'SSGG' 'SIVQ' 'SBIT' 'SDLY' 'SJVL'
#  'SDET' 'SBUY' 'SDJO' 'SNLF' 'SDIO' 'SDVO' 'SNIZ' 'SDVK' 'SIBO' 'SWFX'
#  'SSVA' 'SWMZ' 'SSER' 'SNEJ' 'SNQX' 'SDGR' 'SILC' 'SWUZ' 'SDSC' 'SBTA'
#  'SWEW' 'SBJU' 'SSGA' 'SDUB' 'SSCN' 'SSUB' 'SNWC' 'SWYV' 'SBLJ' 'SJBH'
#  'SBFS' 'SNJK' 'SNME' 'SWVC' 'SJNP' 'SNOF' 'SWFV' 'SDQG' 'SJBY' 'SNCV'
#  'SNBR' 'SJQN' 'SSRS' 'SWJP' 'SNMA' 'SSMW' 'SIJY' 'SNJR' 'SNGX' 'SNMD'
#  'SNDU' 'SDDN' 'SNJI' 'SDTK' 'SSMH' '9PHD' 'SDPA' 'SNGS' 'SBUR' 'SBPF'
#  'SIPB' 'SBLE' 'SNSH' 'SNDH' 'SWSI' 'SNPY' 'SSOS' 'SWEF' 'SJBM' 'SSGB'
#  'SDGX' 'SIXD' 'SNGQ' 'SWUV' 'SBAE' 'SBTR' 'SSZL' 'SJWQ' 'SNBA' 'SBPB'
#  'SNDP' 'SWPM' 'SDOW' 'SSNV' 'SWVI' 'SSGX' 'SNKH' 'SWVR' 'SDTF' 'SSKW'
#  'SWVZ' 'SNJO' 'SNTO' 'SJXM' 'SDNH' '5JTI' 'SNFS' 'SSFC' 'SWGN' 'SIBH'
#  'SJFM' 'SBQV' 'SDTO' 'SDKH' 'SDXF' 'SWGC' 'SWSL' 'SBAQ' 'SWLV' 'SNMU'
#  'SNPD' 'SWKT' 'SDEE' 'SWGL' 'SDNB' 'SWNK' 'SDNI' 'SSKM' 'SSJL' 'SJLU'
#  'SBCJ' 'SDIM' 'SJAH' 'SNNL' 'SWIN' '9PFX' 'SSBR' 'SBPC' 'SNZA' 'SJVO'
#  'SDLZ' 'SBSM' 'SSSE' 'SBHT' 'SIQH' 'SSLT' 'SWPQ' '9PFC' 'SWRZ' 'SNCX'
#  'SJNQ' 'SSSZ' 'SBME' 'SBAR' 'SDMJ' 'SNLO' 'SDVI' 'SNYR' 'SSPB' 'SSJA'
#  'SWJW' 'SING' 'SIQK' 'SD4V' 'SIFV' 'SBBQ' 'SSAK' 'SSQI' 'SNJN' 'SDPG'
#  'SDZX' 'SNPX' 'SNVS' 'SWIT' 'SNYS' 'SJLO' 'SWAQ' 'SDYF' 'SDBN' 'SBFE'
#  'SWQI' 'SIKC' 'SNSG' 'SDWU' 'SWPA' 'SSPV' 'SJDU' 'SWRD' 'SSSS' 'SWMO'
#  'SDJL' 'SDMH' 'SWRO' 'SDWC' 'SSJI' 'SNJD' 'SNOG' 'SNHB' 'SBPK' 'SWKO'
#  'SNKF' 'SIPY' 'SNVC' 'SDMM' 'SDVE' 'SWBE' 'SWMW' 'SDEH' 'SNXW' 'SJYR'
#  'SNCW' 'SSAU' 'SDJC' 'SBTD' 'SNHE' 'SBUA' 'SSAC' 'SNMX' 'SSCP' 'SSPX'
#  'SNBO' 'SDWV' 'SWEI' 'SBKG' 'SNFE' 'SDED' 'SDRE' 'SWUQ' 'SWBB' 'SIJG'
#  'SNAU' 'SSIJ' 'SBAN' 'SNTY' 'SNKK' 'SNPJ' 'SJRG' 'SBIP' 'SIFH' 'SDBK'
#  'SNVB' 'SSPQ' 'SDBA' 'SNUN' 'SSKS' 'SNXR' 'SNGG' 'SSIQ' 'SSPG' 'SNBG'
#  'SDTI' 'SWJN' 'SDYW' 'SBBW' 'SSPL' 'SDHP' 'SSCT' 'SBFN' 'SSDO' 'SSAY'
#  'SSAQ' 'SDJB' 'SDMC' 'SJCY' 'SJFU' 'SNKI' 'SSQT' 'SWOB' 'SDPY' 'SBMY'
#  'SDVL' 'SDPN' 'SSTL' 'SWGP' 'SION' 'SDHU' 'SWNB' 'SNXI' 'SSRZ' 'SDDQ'
#  'SSDP' 'SIPU' 'SNAG' 'SWCZ' 'SNEM' 'SDNE' 'SNGU' 'SNSW' 'SDMV' 'SNYE'
#  'SWYH' 'SNGV' 'SNKE' 'SSSB' 'SSHS' 'SNKB' 'SWUI' 'SSNB' 'SJHR' 'SNAZ'
#  'SBNT' 'SSCR' 'SNTF' 'SBBZ' 'SNOD' 'SNCL' 'SJTO' 'SDBV' 'SIRS' 'SJHG'
#  'SNDR' 'SIBX' 'SDOR' 'SWNO' 'SNIG' 'SWKC' 'SBTK' 'SSTH' 'SBUF' 'SNFJ'
#  'SDKE' 'SWDC' 'SDLO' 'SNWS' 'SSCF' 'SNXT' 'SSPS' 'SSVN' 'SNUZ' 'SBPN'
#  'SWOZ' 'SSUV' 'SNVR']
# -----------------------------------
# ['SP' 'ES' 'MG' 'AM' 'RS' 'PR' 'MT' 'MS' 'GO' 'RR' 'SC' 'PI' 'PA' 'RJ'
#  'BA' 'CE' 'MA' 'PE' 'TO' 'AP' 'DF' 'RO' 'PB' 'RN' 'AL' 'AC' nan 'SE']

# %%
# Checando dados Nulos , ausentes , etc
df.isna().sum()
# Out:
# codigo_ocorrencia                0
# ocorrencia_classificacao         0
# ocorrencia_cidade                0
# ocorrencia_uf                    4
# ocorrencia_aerodromo          2618
# ocorrencia_dia                   0
# ocorrencia_hora                  2
# total_aeronaves_envolvidas       0
# ocorrencia_saida_pista           0
# dtype: int64

# %%
# Calcular a porcentagem de valores nulos em cada coluna
porcentagem_nulos = (df.isnull().sum() / len(df)) * 100

# Exibir a porcentagem de valores nulos em cada coluna
print(round(porcentagem_nulos,1))
# Out:
# codigo_ocorrencia              0.0
# ocorrencia_classificacao       0.0
# ocorrencia_cidade              0.0
# ocorrencia_uf                  0.1
# ocorrencia_aerodromo          38.7
# ocorrencia_dia                 0.0
# ocorrencia_hora                0.0
# total_aeronaves_envolvidas     0.0
# ocorrencia_saida_pista         0.0
# dtype: float64

# %%
# Backup local do df com dados do aerodromo
dfback2 = df.copy()

# %%
# Retirada de colunas com problemas e/ou não utilizadas na analise
df.drop(['ocorrencia_aerodromo'],axis=1,inplace=True)

# %%
# Checando dados Nulos , ausentes , etc
df.isna().sum()
# Out:
# codigo_ocorrencia             0
# ocorrencia_classificacao      0
# ocorrencia_cidade             0
# ocorrencia_uf                 4
# ocorrencia_dia                0
# ocorrencia_hora               2
# total_aeronaves_envolvidas    0
# ocorrencia_saida_pista        0
# dtype: int64

# %%
# Remover linhas com valores NaN
df = df.dropna()

# %%
# Checando dados Nulos , ausentes , etc
df.isna().sum()
# Out:
# codigo_ocorrencia             0
# ocorrencia_classificacao      0
# ocorrencia_cidade             0
# ocorrencia_uf                 0
# ocorrencia_dia                0
# ocorrencia_hora               0
# total_aeronaves_envolvidas    0
# ocorrencia_saida_pista        0
# dtype: int64

# %%
# Verificar dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6763 entries, 0 to 6768
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   codigo_ocorrencia           6763 non-null   int64
#  1   ocorrencia_classificacao    6763 non-null   object
#  2   ocorrencia_cidade           6763 non-null   object
#  3   ocorrencia_uf               6763 non-null   object
#  4   ocorrencia_dia              6763 non-null   object
#  5   ocorrencia_hora             6763 non-null   object
#  6   total_aeronaves_envolvidas  6763 non-null   int64
#  7   ocorrencia_saida_pista      6763 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 475.5+ KB

# %%
# Renomeando colunas
df.rename(columns={'codigo_ocorrencia':'código',
                   'ocorrencia_classificacao':'classificacao',
                   'ocorrencia_cidade':'cidade',
                   'ocorrencia_uf':'uf',
                   'ocorrencia_dia': 'data',
                   'ocorrencia_hora': 'hora',
                   'total_aeronaves_envolvidas':'n_aeronaves',
                   'ocorrencia_saida_pista':'saida_pista'},inplace=True)

# %%
# Mostrar o dataframe
df.tail()
# Out:
#       código classificacao              cidade  uf        data      hora  \
# 6764   40324     INCIDENTE             PELOTAS  RS  05/01/2010  19:25:00
# 6765   39527      ACIDENTE  LUCAS DO RIO VERDE  MT  04/01/2010  17:30:00
# 6766   40211     INCIDENTE      RIO DE JANEIRO  RJ  03/01/2010  12:00:00
# 6767   40349     INCIDENTE               BELÉM  PA  03/01/2010  11:05:00
# 6768   40351     INCIDENTE      RIO DE JANEIRO  RJ  03/01/2010  03:00:00
#
#       n_aeronaves saida_pista
# 6764            1         NÃO
# 6765            1         NÃO
# 6766            1         NÃO
# 6767            1         NÃO
# 6768            1         NÃO

# %%
# Tipos de dados
df.dtypes
# Out:
# código            int64
# classificacao    object
# cidade           object
# uf               object
# data             object
# hora             object
# n_aeronaves       int64
# saida_pista      object
# dtype: object

# %%
# Transformação do tipo de dados da coluna código
df['código'] = df['código'].astype(str)

# %%
# Converter o tipo da coluna para datetime64[ns]
df['data'] = df['data'].astype('datetime64[ns]')

# %%
# Ano
df['ano'] = df.data.dt.year

# Mês
df['mês'] = df.data.dt.month

# Dia
df['dia'] = df.data.dt.day

# %%
# Converter a coluna para o tipo de dado 'string'
df['hora'] = df['hora'].astype(str)

# %%
# Realizar o split e salvar apenas a parte da hora em uma nova coluna 'horario'
df['horario'] = df['hora'].str.split(':').str[0]

# %%
# Retirada de colunas com problemas e/ou não utilizadas na analise
df.drop(['hora'],axis=1,inplace=True)

# %%
# Verificação do dataframe
df.head()
# Out:
#   código    classificacao          cidade  uf       data  n_aeronaves  \
# 0  81027  INCIDENTE GRAVE       SÃO PAULO  SP 2022-09-10            1
# 1  81030        INCIDENTE         VITÓRIA  ES 2022-09-10            1
# 2  81023  INCIDENTE GRAVE       AMERICANA  SP 2022-06-10            1
# 3  81029        INCIDENTE  BELO HORIZONTE  MG 2022-06-10            1
# 4  81025        INCIDENTE          MANAUS  AM 2022-05-10            1
#
#   saida_pista   ano  mês  dia horario
# 0         SIM  2022    9   10      16
# 1         NÃO  2022    9   10      16
# 2         SIM  2022    6   10      15
# 3         NÃO  2022    6   10      00
# 4         NÃO  2022    5   10      20

# %%
# Converter a coluna para o tipo de dado 'int'
df['horario'] = df['horario'].astype(int)

# %%
# Checando dados Nulos , ausentes , etc
df.isna().sum()
# Out:
# código           0
# classificacao    0
# cidade           0
# uf               0
# data             0
# n_aeronaves      0
# saida_pista      0
# ano              0
# mês              0
# dia              0
# horario          0
# dtype: int64

# %%
# Verificação final dos tipos de dados do dataframe
df.dtypes
# Out:
# código                   object
# classificacao            object
# cidade                   object
# uf                       object
# data             datetime64[ns]
# n_aeronaves               int64
# saida_pista              object
# ano                       int64
# mês                       int64
# dia                       int64
# horario                   int64
# dtype: object

# %% [markdown]
# # **Qualidade dos Dados**

# %% [markdown]
# **Validação Schema:** No geral, essa linha de código define o esquema de um DataFrame, especificando os tipos de dados e as restrições para cada coluna. Isso pode ser usado para validar e garantir a integridade dos dados ao criar ou manipular DataFrames no pandas.

# %% [markdown]
# Ao chamar schema.validate(df), o DataFrame df é validado em relação ao schema. Isso significa que cada coluna do DataFrame é verificada em relação às regras e restrições definidas no schema. Se alguma coluna não atender às regras, uma exceção será lançada indicando o motivo da falha na validação.

# %%
# Nossas colunas do dataframe
df.dtypes
# Out:
# código                   object
# classificacao            object
# cidade                   object
# uf                       object
# data             datetime64[ns]
# n_aeronaves               int64
# saida_pista              object
# ano                       int64
# mês                       int64
# dia                       int64
# horario                   int64
# dtype: object

# %%
# Esse código está com erro no nome das colunas year, month, day em que passamos para portugues  e por isso vai acusar erro.
# Definir o esquema de validação
'''
schema = pa.DataFrameSchema({'código': pa.Column(pa.String),
                            'classificacao': pa.Column(pa.String),
                            'cidade': pa.Column(pa.String),
                            'uf': pa.Column(pa.String),
                            'data': pa.Column(pa.DateTime),
                            'n_aeronaves': pa.Column(pa.Int),
                            'saida_pista': pa.Column(pa.String),
                            'year': pa.Column(pa.Int),
                            'month': pa.Column(pa.Int),
                            'day': pa.Column(pa.Int),
                            'horario': pa.Column(pa.Int)
                            })

# Validar o DataFrame
schema.validate(df)
'''
# Out:
# "\nschema = pa.DataFrameSchema({'código': pa.Column(pa.String),\n                            'classificacao': pa.Column(pa.String),\n                            'cidade': pa.Column(pa.String),\n                            'uf': pa.Column(pa.String),\n                            'data': pa.Column(pa.DateTime),\n                            'n_aeronaves': pa.Column(pa.Int),\n                            'saida_pista': pa.Column(pa.String),\n                            'year': pa.Column(pa.Int),\n                            'month': pa.Column(pa.Int),\n                            'day': pa.Column(pa.Int),\n                            'horario': pa.Column(pa.Int)\n                            })\n\n# Validar o DataFrame\nschema.validate(df)\n"

# %%
# Definir o esquema de validação
schema = pa.DataFrameSchema({'código': pa.Column(pa.String),
                            'classificacao': pa.Column(pa.String),
                            'cidade': pa.Column(pa.String),
                            'uf': pa.Column(pa.String),
                            'data': pa.Column(pa.DateTime),
                            'n_aeronaves': pa.Column(pa.Int),
                            'saida_pista': pa.Column(pa.String),
                            'ano': pa.Column(pa.Int),
                            'mês': pa.Column(pa.Int),
                            'dia': pa.Column(pa.Int),
                            'horario': pa.Column(pa.Int)
                            })

# Validar o DataFrame
schema.validate(df)
# Out:
#      código    classificacao              cidade  uf       data  n_aeronaves  \
# 0     81027  INCIDENTE GRAVE           SÃO PAULO  SP 2022-09-10            1
# 1     81030        INCIDENTE             VITÓRIA  ES 2022-09-10            1
# 2     81023  INCIDENTE GRAVE           AMERICANA  SP 2022-06-10            1
# 3     81029        INCIDENTE      BELO HORIZONTE  MG 2022-06-10            1
# 4     81025        INCIDENTE              MANAUS  AM 2022-05-10            1
# ...     ...              ...                 ...  ..        ...          ...
# 6764  40324        INCIDENTE             PELOTAS  RS 2010-05-01            1
# 6765  39527         ACIDENTE  LUCAS DO RIO VERDE  MT 2010-04-01            1
# 6766  40211        INCIDENTE      RIO DE JANEIRO  RJ 2010-03-01            1
# 6767  40349        INCIDENTE               BELÉM  PA 2010-03-01            1
# 6768  40351        INCIDENTE      RIO DE JANEIRO  RJ 2010-03-01            1
#
#      saida_pista   ano  mês  dia  horario
# 0            SIM  2022    9   10       16
# 1            NÃO  2022    9   10       16
# 2            SIM  2022    6   10       15
# 3            NÃO  2022    6   10        0
# 4            NÃO  2022    5   10       20
# ...          ...   ...  ...  ...      ...
# 6764         NÃO  2010    5    1       19
# 6765         NÃO  2010    4    1       17
# 6766         NÃO  2010    3    1       12
# 6767         NÃO  2010    3    1       11
# 6768         NÃO  2010    3    1        3
#
# [6763 rows x 11 columns]

# %%
# Backup local do df tratado
dfback3 = df.copy()

# %% [markdown]
# A mensagem de erro significa que o esquema espera que a coluna 'n_aeronaves' seja do tipo 'int64' (números inteiros), mas o tipo encontrado é 'object' (geralmente, uma indicação de uma coluna contendo valores de tipo misto ou texto). Para corrigir o problema, é necessário garantir que a coluna 'n_aeronaves' contenha apenas valores numéricos inteiros.

# %%
# A validação apresentará erro porque no n_aeronaves possui um valor como string e a validação acusará isso.
# Definir o DataFrame de exemplo com uma violação

df_exemplo = pd.DataFrame({'código': ['ABC123', 'DEF456', 'GHI789'],
                           'classificacao': ['A', 'B', 'C'],
                           'cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte'],
                           'uf': ['SP', 'RJ', 'MG'],
                           'data': pd.to_datetime(['2023-01-01', '2023-02-01', '2023-03-01']),
                           'n_aeronaves': ['1', 2, 3],
                           'saida_pista': ['Sim', 'Não', 'Sim'],
                           'year': [2023, 2023, 2023],
                           'month': [1, 2, 3],
                           'day': [1, 1, 1],
                           'horario': ['12:34:56', '08:45:00', '18:15:30']
                          })

df_exemplo
# Out:
#    código classificacao          cidade  uf       data n_aeronaves  \
# 0  ABC123             A       São Paulo  SP 2023-01-01           1
# 1  DEF456             B  Rio de Janeiro  RJ 2023-02-01           2
# 2  GHI789             C  Belo Horizonte  MG 2023-03-01           3
#
#   saida_pista  year  month  day   horario
# 0         Sim  2023      1    1  12:34:56
# 1         Não  2023      2    1  08:45:00
# 2         Sim  2023      3    1  18:15:30

# %%
# Converter a coluna para o tipo de dado 'int'
df_exemplo['n_aeronaves'] = df_exemplo['n_aeronaves'].astype(int)

# %%
# Verificação de tipos
df_exemplo.dtypes
# Out:
# código                   object
# classificacao            object
# cidade                   object
# uf                       object
# data             datetime64[ns]
# n_aeronaves               int64
# saida_pista              object
# year                      int64
# month                     int64
# day                       int64
# horario                  object
# dtype: object

# %%
# Exemplo de violação
# Definir o esquema de validação
schema = pa.DataFrameSchema({'código': pa.Column(pa.String),
                            'classificacao': pa.Column(pa.String),
                            'cidade': pa.Column(pa.String),
                            'uf': pa.Column(pa.String),
                            'data': pa.Column(pa.DateTime),
                            'n_aeronaves': pa.Column(pa.Int),
                            'saida_pista': pa.Column(pa.String),
                            'year': pa.Column(pa.Int),
                            'month': pa.Column(pa.Int),
                            'day': pa.Column(pa.Int),
                            'horario': pa.Column(pa.String),
                            })

# Validar o DataFrame
schema.validate(df_exemplo)
# Out:
#    código classificacao          cidade  uf       data  n_aeronaves  \
# 0  ABC123             A       São Paulo  SP 2023-01-01            1
# 1  DEF456             B  Rio de Janeiro  RJ 2023-02-01            2
# 2  GHI789             C  Belo Horizonte  MG 2023-03-01            3
#
#   saida_pista  year  month  day   horario
# 0         Sim  2023      1    1  12:34:56
# 1         Não  2023      2    1  08:45:00
# 2         Sim  2023      3    1  18:15:30

# %% [markdown]
# ## **CARREGAMENTO**

# %%
# Exportação em uma pasta Google Drive
#df.to_csv('/content/drive/MyDrive/Semana 6 - Python para Análise de Dados/cenipa_tratado.csv',index=False)

# %%
# Exportação no Google Drive. Obs.: ao fechar o colab esse arquivo some. Recomendação: faça o download e coloque numa pasta do google drive
#df.to_csv('cenipa_tratado.csv', index=False)

# %%
# Google Cloud
df.to_csv('gs://projetos-aula/projeto-cenipa/tratado/cenipa_tratado.csv', index=False) # salva no bucket

# %% [markdown]
# # **ANÁLISES**

# %% [markdown]
# ### **Busca ou localização (query)**

# %%
# Tabela resultante do nosso problema
df.head()
# Out:
#   código    classificacao          cidade  uf       data  n_aeronaves  \
# 0  81027  INCIDENTE GRAVE       SÃO PAULO  SP 2022-09-10            1
# 1  81030        INCIDENTE         VITÓRIA  ES 2022-09-10            1
# 2  81023  INCIDENTE GRAVE       AMERICANA  SP 2022-06-10            1
# 3  81029        INCIDENTE  BELO HORIZONTE  MG 2022-06-10            1
# 4  81025        INCIDENTE          MANAUS  AM 2022-05-10            1
#
#   saida_pista   ano  mês  dia  horario
# 0         SIM  2022    9   10       16
# 1         NÃO  2022    9   10       16
# 2         SIM  2022    6   10       15
# 3         NÃO  2022    6   10        0
# 4         NÃO  2022    5   10       20

# %%
# Localização de uma linha (primeira linha) [utilize o número que quiser dentro do colchete]
# Pesquisar iloc
df.loc[0]
# Out:
# código                         81027
# classificacao        INCIDENTE GRAVE
# cidade                     SÃO PAULO
# uf                                SP
# data             2022-09-10 00:00:00
# n_aeronaves                        1
# saida_pista                      SIM
# ano                             2022
# mês                                9
# dia                               10
# horario                           16
# Name: 0, dtype: object

# %%
# Localização de um conjunto de linhas
df.loc[1000:1002]
# Out:
#      código    classificacao                cidade  uf       data  \
# 1000  79801  INCIDENTE GRAVE                 CANTÁ  RR 2021-07-01
# 1001  79805        INCIDENTE             GUARULHOS  SP 2021-07-01
# 1002  79865        INCIDENTE  GOVERNADOR VALADARES  MG 2021-07-01
#
#       n_aeronaves saida_pista   ano  mês  dia  horario
# 1000            1         NÃO  2021    7    1       12
# 1001            1         NÃO  2021    7    1        2
# 1002            1         NÃO  2021    7    1       15

# %%
# Troque o valor linha 0 da coluna "cidade” por Campo Grande
df.loc[0,'cidade'] = 'CAMPO GRANDE'

# %%
# Voltando ao que era antes da mudança
df.loc[0,'cidade'] = 'SÃO PAULO'

# %%
# Troque a coluna "cidade” inteira por Campo Grande
df.loc[:,'cidade'] = 'CAMPO GRANDE'

# %%
# Retornando ao que era antes com utilização do backup tratado
df = dfback3

# %%
# Busca avançada: linhas e colunas especificas
df.loc[[0,1000,2000], ['classificacao', 'uf']]
# Out:
#         classificacao  uf
# 0     INCIDENTE GRAVE  SP
# 1000  INCIDENTE GRAVE  RR
# 2000        INCIDENTE  PB

# %%
# Trocar um valor especifico na coluna.
df.loc[df.classificacao == 'INCIDENTE GRAVE', ['classificacao']] = 'TESTE'

# %%
# Retornando o valor especifico na coluna.
df.loc[df.classificacao == 'TESTE', ['classificacao']] = 'INCIDENTE GRAVE'

# %%
# Atenção ao trocar dados, mantenha sempre o tipo.
df.loc[0,'n_aeronaves'] = 1           # Originalmente é int 1
df.loc[0,'n_aeronaves'] = '1'         # Na troca ficou str 1 (Não pode acontecer!)

# %%
# Revertendo para int - Não funciona
df.loc[0,'n_aeronaves'] = 1

# %%
# Converter a coluna para o tipo de dado 'int'
df['n_aeronaves'] = df['n_aeronaves'].astype(int)

# %%
# Checagem da mudança de tipo de dado
df.dtypes
# Out:
# código                   object
# classificacao            object
# cidade                   object
# uf                       object
# data             datetime64[ns]
# n_aeronaves               int64
# saida_pista              object
# ano                       int64
# mês                       int64
# dia                       int64
# horario                   int64
# dtype: object

# %%
# Visualização do df
df.head()
# Out:
#   código    classificacao          cidade  uf       data  n_aeronaves  \
# 0  81027  INCIDENTE GRAVE       SÃO PAULO  SP 2022-09-10            1
# 1  81030        INCIDENTE         VITÓRIA  ES 2022-09-10            1
# 2  81023  INCIDENTE GRAVE       AMERICANA  SP 2022-06-10            1
# 3  81029        INCIDENTE  BELO HORIZONTE  MG 2022-06-10            1
# 4  81025        INCIDENTE          MANAUS  AM 2022-05-10            1
#
#   saida_pista   ano  mês  dia  horario
# 0         SIM  2022    9   10       16
# 1         NÃO  2022    9   10       16
# 2         SIM  2022    6   10       15
# 3         NÃO  2022    6   10        0
# 4         NÃO  2022    5   10       20

# %%
# Checagem da mudança de tipo de dado
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6763 entries, 0 to 6768
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   código         6763 non-null   object
#  1   classificacao  6763 non-null   object
#  2   cidade         6763 non-null   object
#  3   uf             6763 non-null   object
#  4   data           6763 non-null   datetime64[ns]
#  5   n_aeronaves    6763 non-null   int64
#  6   saida_pista    6763 non-null   object
#  7   ano            6763 non-null   int64
#  8   mês            6763 non-null   int64
#  9   dia            6763 non-null   int64
#  10  horario        6763 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 892.1+ KB

# %% [markdown]
# ### **Filtro**

# %%
# Guardar as posições de valores ‘ACIDENTE’
filtro_acidente = df.classificacao =='ACIDENTE'

# Transformando e salvando a filtragem em um novo df.
df_filtro_acidente  = df.loc[filtro_acidente]
df_filtro_acidente
# Out:
#      código classificacao              cidade  uf       data  n_aeronaves  \
# 5     81019      ACIDENTE        PORTO ALEGRE  RS 2022-03-10            1
# 7     81021      ACIDENTE   NOVA BANDEIRANTES  MT 2022-02-10            1
# 12    81014      ACIDENTE           BOA VISTA  RR 2022-09-27            1
# 15    81018      ACIDENTE             LONTRAS  SC 2022-09-24            1
# 19    80998      ACIDENTE   ENGENHEIRO CALDAS  MG 2022-09-21            1
# ...     ...           ...                 ...  ..        ...          ...
# 6750  39315      ACIDENTE            CANUTAMA  AM 2010-01-15            1
# 6754  40107      ACIDENTE              GURUPÁ  PA 2010-12-01            1
# 6755  39507      ACIDENTE  PRIMAVERA DO LESTE  MT 2010-11-01            1
# 6759  40069      ACIDENTE           SÃO PAULO  SP 2010-10-01            1
# 6765  39527      ACIDENTE  LUCAS DO RIO VERDE  MT 2010-04-01            1
#
#      saida_pista   ano  mês  dia  horario
# 5            NÃO  2022    3   10       20
# 7            SIM  2022    2   10       19
# 12           NÃO  2022    9   27        0
# 15           NÃO  2022    9   24       20
# 19           NÃO  2022    9   21       17
# ...          ...   ...  ...  ...      ...
# 6750         NÃO  2010    1   15       21
# 6754         NÃO  2010   12    1       14
# 6755         NÃO  2010   11    1       17
# 6759         NÃO  2010   10    1       14
# 6765         NÃO  2010    4    1       17
#
# [2087 rows x 11 columns]

# %%
# Visualização do novo dataframe
df_filtro_acidente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2087 entries, 5 to 6765
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   código         2087 non-null   object
#  1   classificacao  2087 non-null   object
#  2   cidade         2087 non-null   object
#  3   uf             2087 non-null   object
#  4   data           2087 non-null   datetime64[ns]
#  5   n_aeronaves    2087 non-null   int64
#  6   saida_pista    2087 non-null   object
#  7   ano            2087 non-null   int64
#  8   mês            2087 non-null   int64
#  9   dia            2087 non-null   int64
#  10  horario        2087 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 195.7+ KB

# %%
# Exportação do filtro
df_filtro_acidente.to_csv('df_filtro_acidente.csv', index=False)

# %%
# Usando o banco de dados com dfback2
dfback2.head()
# Out:
#    codigo_ocorrencia ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0              81027          INCIDENTE GRAVE         SÃO PAULO            SP
# 1              81030                INCIDENTE           VITÓRIA            ES
# 2              81023          INCIDENTE GRAVE         AMERICANA            SP
# 3              81029                INCIDENTE    BELO HORIZONTE            MG
# 4              81025                INCIDENTE            MANAUS            AM
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0                 SBSP     09/10/2022        16:30:00
# 1                 SBVT     09/10/2022        16:20:00
# 2                 SDAI     06/10/2022        15:30:00
# 3                 SBBH     06/10/2022        00:44:00
# 4                 SBEG     05/10/2022        20:56:00
#
#    total_aeronaves_envolvidas ocorrencia_saida_pista
# 0                           1                    SIM
# 1                           1                    NÃO
# 2                           1                    SIM
# 3                           1                    NÃO
# 4                           1                    NÃO

# %%
# É um tipo de filtro para observação de dados ausentes
dfback2.isna().sum()
# Out:
# codigo_ocorrencia                0
# ocorrencia_classificacao         0
# ocorrencia_cidade                0
# ocorrencia_uf                    4
# ocorrencia_aerodromo          2618
# ocorrencia_dia                   0
# ocorrencia_hora                  2
# total_aeronaves_envolvidas       0
# ocorrencia_saida_pista           0
# dtype: int64

# %%
# Guardar as posições de valores ausentes
filtro_nulo = dfback2.ocorrencia_aerodromo.isna()

# Mostrar df com dados ausentes em cinco posições
dfback2.loc[filtro_nulo].head()
# Out:
#    codigo_ocorrencia ocorrencia_classificacao  ocorrencia_cidade  \
# 5              81019                 ACIDENTE       PORTO ALEGRE
# 6              81022                INCIDENTE             LOBATO
# 7              81021                 ACIDENTE  NOVA BANDEIRANTES
# 8              81009          INCIDENTE GRAVE            NAVIRAÍ
# 9              81012                INCIDENTE           LINHARES
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 5            RS                  NaN     03/10/2022        20:50:00
# 6            PR                  NaN     03/10/2022        15:38:00
# 7            MT                  NaN     02/10/2022        19:00:00
# 8            MS                  NaN     01/10/2022        10:10:00
# 9            ES                  NaN     30/09/2022        12:20:00
#
#    total_aeronaves_envolvidas ocorrencia_saida_pista
# 5                           1                    NÃO
# 6                           1                    NÃO
# 7                           1                    SIM
# 8                           1                    SIM
# 9                           1                    NÃO

# %%
# Chamando nossa df tratada
df.head()
# Out:
#   código    classificacao          cidade  uf       data  n_aeronaves  \
# 0  81027  INCIDENTE GRAVE       SÃO PAULO  SP 2022-09-10            1
# 1  81030        INCIDENTE         VITÓRIA  ES 2022-09-10            1
# 2  81023  INCIDENTE GRAVE       AMERICANA  SP 2022-06-10            1
# 3  81029        INCIDENTE  BELO HORIZONTE  MG 2022-06-10            1
# 4  81025        INCIDENTE          MANAUS  AM 2022-05-10            1
#
#   saida_pista   ano  mês  dia  horario
# 0         SIM  2022    9   10       16
# 1         NÃO  2022    9   10       16
# 2         SIM  2022    6   10       15
# 3         NÃO  2022    6   10        0
# 4         NÃO  2022    5   10       20

# %%
# Filtro com mais detalhes: com muitas informações
ft_cidade = df.cidade == 'SÃO PAULO'
ft_pista = df.saida_pista == 'SIM'
ft_2021 = df.data.dt.year == 2021
ft_uf = df.uf == 'SP'

df.loc[ft_cidade & ft_pista & ft_2021 & ft_uf]
# Out:
#     código classificacao     cidade  uf       data  n_aeronaves saida_pista  \
# 465  80456     INCIDENTE  SÃO PAULO  SP 2021-12-30            1         SIM
#
#       ano  mês  dia  horario
# 465  2021   12   30       13

# %%
# Outra forma de filtragem no ano
ft_cidade = df.cidade == 'SÃO PAULO'
ft_pista = df.saida_pista == 'SIM'
ft_2021 = df.ano == 2021
ft_uf = df.uf == 'SP'

df.loc[ft_cidade & ft_pista & ft_2021 & ft_uf]
# Out:
#     código classificacao     cidade  uf       data  n_aeronaves saida_pista  \
# 465  80456     INCIDENTE  SÃO PAULO  SP 2021-12-30            1         SIM
#
#       ano  mês  dia  horario
# 465  2021   12   30       13

# %%
# Filtro com mais detalhes: com data
ft_abril = df.data.dt.month == 4
ft_quinz = (df.data.dt.day > 0) & (df.data.dt.day < 16)

# Resultado do filtro
df.loc[ft_abril & ft_quinz]
# Out:
#      código    classificacao              cidade  uf       data  n_aeronaves  \
# 47    80975        INCIDENTE      BELO HORIZONTE  MG 2022-04-09            1
# 104   80898  INCIDENTE GRAVE            LONDRINA  PR 2022-04-08            1
# 105   80900        INCIDENTE           PETROLINA  PE 2022-04-08            1
# 152   80834        INCIDENTE              ILHÉUS  BA 2022-04-07            1
# 153   80836         ACIDENTE         RUY BARBOSA  BA 2022-04-07            1
# ...     ...              ...                 ...  ..        ...          ...
# 6650  40251        INCIDENTE       FLORIANÓPOLIS  SC 2010-04-04            1
# 6651  40267  INCIDENTE GRAVE           VERA CRUZ  BA 2010-04-04            1
# 6691  40314        INCIDENTE           SÃO PAULO  SP 2010-04-03            1
# 6723  39316         ACIDENTE        RIO DO OESTE  SC 2010-04-02            1
# 6765  39527         ACIDENTE  LUCAS DO RIO VERDE  MT 2010-04-01            1
#
#      saida_pista   ano  mês  dia  horario
# 47           SIM  2022    4    9       17
# 104          SIM  2022    4    8       21
# 105          NÃO  2022    4    8       18
# 152          NÃO  2022    4    7       21
# 153          NÃO  2022    4    7       12
# ...          ...   ...  ...  ...      ...
# 6650         NÃO  2010    4    4       17
# 6651         NÃO  2010    4    4       11
# 6691         NÃO  2010    4    3       23
# 6723         NÃO  2010    4    2       17
# 6765         NÃO  2010    4    1       17
#
# [266 rows x 11 columns]

# %%
# Filtro para palavras terminadas em RIO
filtro_letras = df.cidade.str[-3:] == 'RIO'
df.loc[filtro_letras]
# Out:
#      código    classificacao                 cidade  uf       data  \
# 649   80256        INCIDENTE              CABO FRIO  RJ 2021-08-21
# 936   79894         ACIDENTE          SÃO DESIDÉRIO  BA 2021-02-16
# 940   79889         ACIDENTE          SÃO DESIDÉRIO  BA 2021-12-02
# 952   79881  INCIDENTE GRAVE              CABO FRIO  RJ 2021-05-02
# 1211  79497         ACIDENTE          SÃO DESIDÉRIO  BA 2020-08-20
# 1278  79407         ACIDENTE          SÃO DESIDÉRIO  BA 2020-06-20
# 1499  79100  INCIDENTE GRAVE                LADÁRIO  MS 2020-01-16
# 1866  78799  INCIDENTE GRAVE              CABO FRIO  RJ 2019-04-18
# 1940  78550         ACIDENTE          SÃO DESIDÉRIO  BA 2019-02-23
# 2178  78102  INCIDENTE GRAVE                 OSÓRIO  RS 2018-04-08
# 2299  77868         ACIDENTE      QUARTO CENTENÁRIO  PR 2018-06-05
# 2344  77785         ACIDENTE                ROSÁRIO  MA 2018-01-04
# 2345  77790        INCIDENTE                ROSÁRIO  MA 2018-01-04
# 2386  77733         ACIDENTE          SÃO DESIDÉRIO  BA 2018-07-03
# 2391  77710         ACIDENTE                 OSÓRIO  RS 2018-04-03
# 2408  77660         ACIDENTE          SÃO DESIDÉRIO  BA 2018-02-18
# 2471  77211        INCIDENTE              CABO FRIO  RJ 2017-12-23
# 2503  77299         ACIDENTE          SÃO DESIDÉRIO  BA 2017-11-26
# 2658  67022        INCIDENTE              CABO FRIO  RJ 2017-07-17
# 2771  66650         ACIDENTE              CABO FRIO  RJ 2017-04-15
# 2821  66489         ACIDENTE           PEDRO OSÓRIO  RS 2017-06-03
# 2835  66549         ACIDENTE           PEDRO OSÓRIO  RS 2017-02-22
# 2857  66362         ACIDENTE          SÃO DESIDÉRIO  BA 2017-04-02
# 3057  65546  INCIDENTE GRAVE                NAZÁRIO  GO 2016-10-08
# 3276  60661         ACIDENTE                 OSÓRIO  RS 2016-01-20
# 3438  53594        INCIDENTE              CABO FRIO  RJ 2015-09-14
# 3612  53229        INCIDENTE              CABO FRIO  RJ 2015-04-20
# 3661  53165  INCIDENTE GRAVE          SÃO DESIDÉRIO  BA 2015-03-20
# 3723  52974         ACIDENTE    PRESIDENTE OLEGÁRIO  MG 2015-02-02
# 3794  52835         ACIDENTE                NAZÁRIO  GO 2014-12-17
# 3903  52553  INCIDENTE GRAVE  SENADOR JOSÉ PORFÍRIO  PA 2014-09-23
# 4131  51004         ACIDENTE          SÃO DESIDÉRIO  BA 2014-04-22
# 4160  51330        INCIDENTE              CABO FRIO  RJ 2014-07-04
# 4233  51019  INCIDENTE GRAVE              CABO FRIO  RJ 2014-02-16
# 4305  51073        INCIDENTE              CABO FRIO  RJ 2014-01-17
# 4320  52940         ACIDENTE      QUARTO CENTENÁRIO  PR 2014-11-01
# 4925  47063        INCIDENTE              CABO FRIO  RJ 2013-06-02
# 5125  46698        INCIDENTE              CABO FRIO  RJ 2012-10-26
# 5264  52063        INCIDENTE              CABO FRIO  RJ 2012-08-15
# 5324  46196        INCIDENTE                 OSÓRIO  RS 2012-09-07
# 5345  46197        INCIDENTE                 OSÓRIO  RS 2012-06-26
# 5377  45946        INCIDENTE              CABO FRIO  RJ 2012-11-06
# 5509  45685        INCIDENTE              CABO FRIO  RJ 2012-03-18
# 5566  45712        INCIDENTE              CABO FRIO  RJ 2012-02-17
# 5809  51778        INCIDENTE              CABO FRIO  RJ 2011-01-09
# 5886  44906        INCIDENTE              CABO FRIO  RJ 2011-07-15
# 5917  44698        INCIDENTE              CABO FRIO  RJ 2011-06-28
# 6735  39318         ACIDENTE  SENADOR JOSÉ PORFÍRIO  PA 2010-01-25
#
#       n_aeronaves saida_pista   ano  mês  dia  horario
# 649             1         NÃO  2021    8   21       15
# 936             1         NÃO  2021    2   16       11
# 940             1         SIM  2021   12    2       13
# 952             1         NÃO  2021    5    2       21
# 1211            1         NÃO  2020    8   20       18
# 1278            1         NÃO  2020    6   20       16
# 1499            1         NÃO  2020    1   16       16
# 1866            2         NÃO  2019    4   18       21
# 1940            1         NÃO  2019    2   23       11
# 2178            2         NÃO  2018    4    8       19
# 2299            1         NÃO  2018    6    5       18
# 2344            1         NÃO  2018    1    4       19
# 2345            1         NÃO  2018    1    4       20
# 2386            1         NÃO  2018    7    3       17
# 2391            1         NÃO  2018    4    3       14
# 2408            1         NÃO  2018    2   18       19
# 2471            1         NÃO  2017   12   23       13
# 2503            1         NÃO  2017   11   26       12
# 2658            1         NÃO  2017    7   17       18
# 2771            1         NÃO  2017    4   15       19
# 2821            1         NÃO  2017    6    3       15
# 2835            1         NÃO  2017    2   22       12
# 2857            1         NÃO  2017    4    2       13
# 3057            1         SIM  2016   10    8       20
# 3276            1         NÃO  2016    1   20       12
# 3438            1         NÃO  2015    9   14       13
# 3612            1         NÃO  2015    4   20       10
# 3661            1         NÃO  2015    3   20       14
# 3723            1         NÃO  2015    2    2       19
# 3794            1         NÃO  2014   12   17       12
# 3903            1         SIM  2014    9   23       20
# 4131            1         NÃO  2014    4   22       19
# 4160            1         NÃO  2014    7    4       17
# 4233            1         NÃO  2014    2   16        9
# 4305            1         NÃO  2014    1   17       10
# 4320            1         NÃO  2014   11    1       10
# 4925            1         NÃO  2013    6    2       17
# 5125            1         NÃO  2012   10   26       15
# 5264            1         NÃO  2012    8   15       15
# 5324            1         NÃO  2012    9    7       12
# 5345            1         NÃO  2012    6   26       17
# 5377            1         NÃO  2012   11    6       14
# 5509            1         NÃO  2012    3   18       12
# 5566            1         NÃO  2012    2   17       12
# 5809            1         NÃO  2011    1    9       13
# 5886            1         NÃO  2011    7   15       16
# 5917            1         NÃO  2011    6   28       11
# 6735            1         NÃO  2010    1   25       16

# %%
# Filtro para letras dentro do valor
# O método str.contains() serve para verificar se cada valor da coluna 'cidade' contém as strings 'BO' ou 'MA'

filtro_interno = df.cidade.str.contains('BO|MA')
df.loc[filtro_interno]
# Out:
#      código    classificacao              cidade  uf       data  n_aeronaves  \
# 4     81025        INCIDENTE              MANAUS  AM 2022-05-10            1
# 12    81014         ACIDENTE           BOA VISTA  RR 2022-09-27            1
# 34    80969        INCIDENTE              MARABÁ  PA 2022-10-09            1
# 72    80947        INCIDENTE              MANAUS  AM 2022-08-20            1
# 92    80964        INCIDENTE              PALMAS  TO 2022-11-08            1
# ...     ...              ...                 ...  ..        ...          ...
# 6690  39916  INCIDENTE GRAVE              MANAUS  AM 2010-07-03            1
# 6733  39487  INCIDENTE GRAVE              PALMAS  TO 2010-01-26            1
# 6750  39315         ACIDENTE            CANUTAMA  AM 2010-01-15            1
# 6755  39507         ACIDENTE  PRIMAVERA DO LESTE  MT 2010-11-01            1
# 6761  39707  INCIDENTE GRAVE            CANUTAMA  AM 2010-09-01            1
#
#      saida_pista   ano  mês  dia  horario
# 4            NÃO  2022    5   10       20
# 12           NÃO  2022    9   27        0
# 34           NÃO  2022   10    9       17
# 72           NÃO  2022    8   20        8
# 92           NÃO  2022   11    8        5
# ...          ...   ...  ...  ...      ...
# 6690         SIM  2010    7    3       19
# 6733         NÃO  2010    1   26       16
# 6750         NÃO  2010    1   15       21
# 6755         NÃO  2010   11    1       17
# 6761         NÃO  2010    9    1       12
#
# [693 rows x 11 columns]

# %%
# Localização via data
df.loc[(df['data']).dt.year == 2019]
# Out:
#      código    classificacao              cidade  uf       data  n_aeronaves  \
# 1524  79068        INCIDENTE               BELÉM  PA 2019-12-31            1
# 1525  79102         ACIDENTE        JUIZ DE FORA  MG 2019-12-31            1
# 1526  79070        INCIDENTE               BELÉM  PA 2019-12-30            1
# 1527  79045         ACIDENTE              GUAÍRA  SP 2019-12-28            1
# 1528  79071        INCIDENTE            CAMPINAS  SP 2019-12-27            1
# ...     ...              ...                 ...  ..        ...          ...
# 2014  78522  INCIDENTE GRAVE  ENGENHEIRO BELTRÃO  PR 2019-03-01            1
# 2015  78411  INCIDENTE GRAVE              RECIFE  PE 2019-02-01            2
# 2016  78391         ACIDENTE             UBATUBA  SP 2019-01-01            1
# 2017  78396  INCIDENTE GRAVE             TUCURUÍ  PA 2019-01-01            1
# 2018  78397         ACIDENTE          PORTO BELO  SC 2019-01-01            1
#
#      saida_pista   ano  mês  dia  horario
# 1524         NÃO  2019   12   31       22
# 1525         SIM  2019   12   31       18
# 1526         NÃO  2019   12   30       18
# 1527         NÃO  2019   12   28        9
# 1528         NÃO  2019   12   27       21
# ...          ...   ...  ...  ...      ...
# 2014         NÃO  2019    3    1       19
# 2015         NÃO  2019    2    1       12
# 2016         NÃO  2019    1    1       13
# 2017         NÃO  2019    1    1       20
# 2018         SIM  2019    1    1       14
#
# [495 rows x 11 columns]

# %%
# Localização via data e mês
df.loc[(df['data'].dt.year == 2019) & (df['data'].dt.month == 3)]
# Out:
#      código    classificacao                 cidade  uf       data  \
# 1560  79023        INCIDENTE                 RECIFE  PE 2019-03-12
# 1561  79024        INCIDENTE                QUIXADÁ  CE 2019-03-12
# 1562  79033         ACIDENTE    OURILÂNDIA DO NORTE  PA 2019-03-12
# 1694  78922        INCIDENTE         RIO DE JANEIRO  RJ 2019-03-09
# 1695  78923  INCIDENTE GRAVE               CANUTAMA  AM 2019-03-09
# 1696  78924        INCIDENTE         RIO DE JANEIRO  RJ 2019-03-09
# 1744  78883        INCIDENTE              SÃO PAULO  SP 2019-03-08
# 1745  78884        INCIDENTE                BOITUVA  SP 2019-03-08
# 1784  78860        INCIDENTE                 CUIABÁ  MT 2019-03-07
# 1785  78861  INCIDENTE GRAVE                PACAJUS  CE 2019-03-07
# 1786  78862        INCIDENTE              SÃO PAULO  SP 2019-03-07
# 1842  78719        INCIDENTE         RIO DE JANEIRO  RJ 2019-03-05
# 1843  78812         ACIDENTE              CONCÓRDIA  SC 2019-03-05
# 1844  78813         ACIDENTE              VILA RICA  MT 2019-03-05
# 1845  78814        INCIDENTE  CAMPOS DOS GOYTACAZES  RJ 2019-03-05
# 1884  78632        INCIDENTE                JUNDIAÍ  SP 2019-03-04
# 1885  78636        INCIDENTE                CONFINS  MG 2019-03-04
# 1889  78625        INCIDENTE         BELO HORIZONTE  MG 2019-03-31
# 1890  78626         ACIDENTE                  GUAPÉ  MG 2019-03-30
# 1891  78638  INCIDENTE GRAVE         BELO HORIZONTE  MG 2019-03-30
# 1892  78627  INCIDENTE GRAVE               GOIATUBA  GO 2019-03-29
# 1893  78620         ACIDENTE  BOM JESUS DOS PERDÕES  SP 2019-03-27
# 1894  78645        INCIDENTE      FRANCISCO BELTRÃO  PR 2019-03-27
# 1895  78628        INCIDENTE         GAVIÃO PEIXOTO  SP 2019-03-26
# 1896  78617         ACIDENTE         NOVA ANDRADINA  MS 2019-03-25
# 1897  78619         ACIDENTE             MONTIVIDIU  GO 2019-03-24
# 1898  78610         ACIDENTE        BENTO GONÇALVES  RS 2019-03-23
# 1899  78612         ACIDENTE         BIRITIBA-MIRIM  SP 2019-03-23
# 1900  78607         ACIDENTE                  MATÃO  SP 2019-03-22
# 1901  78609         ACIDENTE         CAFEZAL DO SUL  PR 2019-03-22
# 1902  78605         ACIDENTE                 CAIABU  SP 2019-03-21
# 1903  78608         ACIDENTE             SANTA INÊS  MA 2019-03-21
# 1904  78623        INCIDENTE             NAVEGANTES  SC 2019-03-21
# 1905  78604        INCIDENTE   SÃO JOSÉ DOS PINHAIS  PR 2019-03-20
# 1906  78599  INCIDENTE GRAVE            TUPACIGUARA  MG 2019-03-19
# 1907  78616         ACIDENTE          CAMPINA VERDE  MG 2019-03-18
# 1908  78624        INCIDENTE             PONTA PORÃ  MS 2019-03-17
# 1909  78596        INCIDENTE                  COARI  AM 2019-03-16
# 1910  78597        INCIDENTE               BRASÍLIA  DF 2019-03-16
# 1911  78603        INCIDENTE   SÃO JOSÉ DOS PINHAIS  PR 2019-03-16
# 1912  78593        INCIDENTE               BRASÍLIA  DF 2019-03-15
# 1913  78591        INCIDENTE              BARREIRAS  BA 2019-03-14
# 1914  78588        INCIDENTE              GUARULHOS  SP 2019-03-13
# 1931  78564         ACIDENTE         RIO DE JANEIRO  RJ 2019-03-03
# 1968  78499        INCIDENTE               SALVADOR  BA 2019-03-02
# 1969  78518  INCIDENTE GRAVE                 JAPURÁ  AM 2019-03-02
# 2014  78522  INCIDENTE GRAVE     ENGENHEIRO BELTRÃO  PR 2019-03-01
#
#       n_aeronaves saida_pista   ano  mês  dia  horario
# 1560            1         NÃO  2019    3   12       12
# 1561            1         NÃO  2019    3   12       11
# 1562            1         NÃO  2019    3   12       13
# 1694            1         NÃO  2019    3    9       22
# 1695            1         NÃO  2019    3    9       14
# 1696            1         NÃO  2019    3    9       12
# 1744            1         NÃO  2019    3    8       17
# 1745            1         NÃO  2019    3    8       21
# 1784            1         NÃO  2019    3    7       15
# 1785            1         NÃO  2019    3    7       10
# 1786            1         NÃO  2019    3    7       18
# 1842            1         NÃO  2019    3    5       16
# 1843            1         NÃO  2019    3    5       21
# 1844            1         NÃO  2019    3    5       11
# 1845            1         NÃO  2019    3    5       10
# 1884            1         NÃO  2019    3    4       13
# 1885            1         NÃO  2019    3    4       20
# 1889            1         NÃO  2019    3   31       17
# 1890            1         NÃO  2019    3   30       15
# 1891            1         NÃO  2019    3   30       18
# 1892            1         SIM  2019    3   29       20
# 1893            1         NÃO  2019    3   27       13
# 1894            1         NÃO  2019    3   27       17
# 1895            1         NÃO  2019    3   26       12
# 1896            1         NÃO  2019    3   25       11
# 1897            1         NÃO  2019    3   24       17
# 1898            1         NÃO  2019    3   23       18
# 1899            1         NÃO  2019    3   23       15
# 1900            1         NÃO  2019    3   22       12
# 1901            1         NÃO  2019    3   22       11
# 1902            1         SIM  2019    3   21       20
# 1903            1         NÃO  2019    3   21       11
# 1904            1         NÃO  2019    3   21       14
# 1905            1         NÃO  2019    3   20       21
# 1906            1         NÃO  2019    3   19       15
# 1907            1         NÃO  2019    3   18       20
# 1908            1         NÃO  2019    3   17       18
# 1909            1         NÃO  2019    3   16       12
# 1910            1         NÃO  2019    3   16       22
# 1911            1         NÃO  2019    3   16        3
# 1912            1         NÃO  2019    3   15       14
# 1913            2         NÃO  2019    3   14       18
# 1914            1         NÃO  2019    3   13        9
# 1931            1         NÃO  2019    3    3       20
# 1968            1         NÃO  2019    3    2       14
# 1969            1         NÃO  2019    3    2       20
# 2014            1         NÃO  2019    3    1       19

# %%
# Consultas avançadas - Pós-aula
df[df['cidade'].str.contains(r'\bRIO\b', regex=True, case=False)]
# Out:
#      código classificacao              cidade  uf       data  n_aeronaves  \
# 30    81026     INCIDENTE      RIO DE JANEIRO  RJ 2022-09-14            1
# 51    80973     INCIDENTE      RIO DE JANEIRO  RJ 2022-02-09            1
# 58    80940      ACIDENTE  RIBAS DO RIO PARDO  MS 2022-08-28            1
# 67    80935     INCIDENTE           RIO CLARO  SP 2022-08-24            1
# 79    80932     INCIDENTE      RIO DE JANEIRO  RJ 2022-08-17            1
# ...     ...           ...                 ...  ..        ...          ...
# 6747  41577     INCIDENTE      RIO DE JANEIRO  RJ 2010-01-19            1
# 6749  44575     INCIDENTE      RIO DE JANEIRO  RJ 2010-01-17            1
# 6765  39527      ACIDENTE  LUCAS DO RIO VERDE  MT 2010-04-01            1
# 6766  40211     INCIDENTE      RIO DE JANEIRO  RJ 2010-03-01            1
# 6768  40351     INCIDENTE      RIO DE JANEIRO  RJ 2010-03-01            1
#
#      saida_pista   ano  mês  dia  horario
# 30           NÃO  2022    9   14        1
# 51           NÃO  2022    2    9       23
# 58           NÃO  2022    8   28       20
# 67           NÃO  2022    8   24       20
# 79           NÃO  2022    8   17        9
# ...          ...   ...  ...  ...      ...
# 6747         NÃO  2010    1   19       12
# 6749         NÃO  2010    1   17       12
# 6765         NÃO  2010    4    1       17
# 6766         NÃO  2010    3    1       12
# 6768         NÃO  2010    3    1        3
#
# [497 rows x 11 columns]

# %% [markdown]
# ### **GroupBy**

# %%
# O método size() mostra a contagem de cada categoria.
df.groupby(['classificacao']).size()
# Out:
# classificacao
# ACIDENTE           2087
# INCIDENTE          3792
# INCIDENTE GRAVE     884
# dtype: int64

# %%
# Ordem descrescente (por padrão True)
df.groupby(['classificacao']).size().sort_values(ascending=False)
# Out:
# classificacao
# INCIDENTE          3792
# ACIDENTE           2087
# INCIDENTE GRAVE     884
# dtype: int64

# %%
# As 10 cidades com maior número de aeronaves envolvidas que sofreram algum acidente
df.groupby('cidade')['n_aeronaves'].sum().sort_values(ascending=False).head(10)
# Out:
# cidade
# RIO DE JANEIRO    374
# SÃO PAULO         330
# BELO HORIZONTE    211
# CAMPINAS          211
# GUARULHOS         186
# GOIÂNIA           170
# BRASÍLIA          159
# LONDRINA          140
# MANAUS            131
# PORTO ALEGRE      115
# Name: n_aeronaves, dtype: int64

# %%
df.groupby(['ano'])['n_aeronaves'].sum()
# Out:
# ano
# 2010    553
# 2011    584
# 2012    651
# 2013    659
# 2014    581
# 2015    472
# 2016    413
# 2017    436
# 2018    456
# 2019    501
# 2020    517
# 2021    561
# 2022    469
# Name: n_aeronaves, dtype: int64

# %%
df.groupby('mês')['n_aeronaves'].sum().sort_values(ascending=False)
# Out:
# mês
# 3     646
# 9     623
# 1     621
# 8     576
# 10    565
# 7     564
# 4     562
# 6     559
# 5     558
# 11    539
# 2     524
# 12    516
# Name: n_aeronaves, dtype: int64

# %%
# Agrupamento desconsiderando valores ausentes
dfback2.groupby(['ocorrencia_aerodromo']).size().sort_values(ascending=False).head(10)
# Out:
# ocorrencia_aerodromo
# SBGR    173
# SBMT    150
# SBKP    128
# SBBH    124
# SBGL    107
# SBBR    104
# SBLO    102
# SBPA     84
# SBEG     82
# SBSP     82
# dtype: int64

# %%
# Considerando valores ausentes (Recomendado)
dfback2.groupby(['ocorrencia_aerodromo'],dropna=False).size().sort_values(ascending=False).head(10)
# Out:
# ocorrencia_aerodromo
# NaN     2618
# SBGR     173
# SBMT     150
# SBKP     128
# SBBH     124
# SBGL     107
# SBBR     104
# SBLO     102
# SBPA      84
# SBSP      82
# dtype: int64

# %% [markdown]
# ### **Combinando filtro e agrupamento**

# %% [markdown]
# O método isin() é usado principalmente para filtrar ou selecionar linhas em um DataFrame com base em uma condição de pertencimento a um conjunto de valores. É útil quando você deseja extrair apenas as linhas que correspondem a determinados valores de uma coluna.

# %%
# Filtros
filtro_incidente = df.classificacao =='INCIDENTE'
filtro_sul = df.uf.isin(['RS','PR','SC'])           # método isin() usado para selecionar as regiões.

# Filtros juntos: incidentes e sul
dfsul = df.loc[filtro_incidente & filtro_sul]       # incidentes dos Estados da Região Sul

# Agrupamento
dfsul.groupby(['uf']).size().sort_values(ascending=False) # Contagem
# Out:
# uf
# PR    316
# RS    157
# SC    132
# dtype: int64

# %% [markdown]
# # **VISUALIZAÇÃO**

# %% [markdown]
# * Grafico de barras
# * Gráfico de setores
# * Grafico de linha
# * Gráficos empilhados
#
# * Pandas: https://pandas.pydata.org/docs/reference/frame.html
# * Matplotlib: https://matplotlib.org/stable/plot_types/index
# * Seaborn: https://seaborn.pydata.org/
#
# * Bônus Plotly: https://plotly.com/python/getting-started/#jupyter-notebook-support
#
# * Cores do matplotlib: https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
# Abertura de biblioteca de visualização
import matplotlib.pyplot as plt

# %%
# Gráfico de barras horizontal
df.groupby(['classificacao']).size().plot.barh(figsize=(7,5), color=['skyblue'])
plt.xlabel('Contagem')
plt.ylabel('Classificação')
plt.title('Contagem de Ocorrências por Classificação')
plt.show()

# %%
# Gráfico de barras vertical
df.groupby('uf').size().sort_values(ascending=False).plot.bar(figsize=(7,5), color=['DarkCyan'])
plt.xlabel('Estado')
plt.ylabel('Contagem')
plt.title('Contagem de Ocorrências por Estado')
plt.show()

# %%
# Gráfico de barras empilhadas da contagem de ocorrências por 'uf' e 'classificacao':
df.groupby(['uf', 'classificacao']).size().unstack().plot(kind='bar', stacked=True)
plt.xlabel('UF')
plt.ylabel('Contagem')
plt.title('Contagem de Ocorrências por UF e Classificação')
plt.legend(title='Classificação')
plt.show()

# %%
# Gráfico de setores
colors = ['#FA8072', '#FFDAB9']
df.groupby(['saida_pista'],dropna=False).size().sort_values(ascending=False).plot(kind='pie',
                                                                                  ylabel= 'Saída da Pista',
                                                                                  figsize=(7, 5),
                                                                                  autopct='%1.0f%%',
                                                                                  startangle=90,
                                                                                  colors=colors)
plt.title('Percentual de ocorrências que sairam da Pista')
plt.show()

# %%
# Gráfico de linha da contagem de ocorrências ao longo do tempo por ano:
df.groupby(df['data'].dt.year).size().plot(kind='line')
plt.xlabel('Ano')
plt.ylabel('Contagem')
plt.title('Contagem de Ocorrências ao Longo do Tempo por Ano')
plt.show()

# %% [markdown]
# # **Estatística**

# %% [markdown]
# * Medidas importantes para o analista de dados: media, mediana, moda, quartis e desv. padrão
#
# * Gráficos importantes para o analista de dados: Barras, setores, linhas, dispersão, histograma e boxplot

# %% [markdown]
# ![Foto 6.png](data:image/png;base64,...)

# %% [markdown]
# # **ADICIONAIS IMPORTANTES**

# %% [markdown]
# ### Duplicadas

# %% [markdown]
# Documentação para estudar as duplicadas: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

# %%
# Verificação e retirada de duplicadas
import pandas as pd

# Montando um DataFrame genérico para estudarmos o conceio
df_duplicada = pd.DataFrame({'nome': ['João', 'Maria', 'Lucas', 'Ana', 'Carlos', 'Maria'],
                            'idade': [25, 30, 28, 35, 40, 30],
                            'cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Salvador', 'Brasília', 'Rio de Janeiro'],
                            'profissão': ['Engenheiro', 'Advogada', 'Professor', 'Médica', 'Empresário', 'Advogada']})

df_duplicada
# Out:
#      nome  idade          cidade   profissão
# 0    João     25       São Paulo  Engenheiro
# 1   Maria     30  Rio de Janeiro    Advogada
# 2   Lucas     28  Belo Horizonte   Professor
# 3     Ana     35        Salvador      Médica
# 4  Carlos     40        Brasília  Empresário
# 5   Maria     30  Rio de Janeiro    Advogada

# %%
# Por padrão, ele remove linhas duplicadas com base em todas as colunas.
df_duplicada.drop_duplicates()
# Out:
#      nome  idade          cidade   profissão
# 0    João     25       São Paulo  Engenheiro
# 1   Maria     30  Rio de Janeiro    Advogada
# 2   Lucas     28  Belo Horizonte   Professor
# 3     Ana     35        Salvador      Médica
# 4  Carlos     40        Brasília  Empresário

# %%
# Verificação e retirada de duplicadas
import pandas as pd

# Montando um DataFrame genérico para estudarmos o conceio
df_duplicada = pd.DataFrame({'nome': ['João', 'Maria', 'Lucas', 'Ana', 'Carlos', 'Maria'],
                            'idade': [25, 30, 28, 35, 40, 30],
                            'cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Salvador', 'Brasília', 'Rio de Janeiro'],
                            'profissão': ['Engenheiro', 'Advogada', 'Professor', 'Médica', 'Empresário', 'Advogada']})

df_duplicada
# Out:
#      nome  idade          cidade   profissão
# 0    João     25       São Paulo  Engenheiro
# 1   Maria     30  Rio de Janeiro    Advogada
# 2   Lucas     28  Belo Horizonte   Professor
# 3     Ana     35        Salvador      Médica
# 4  Carlos     40        Brasília  Empresário
# 5   Maria     30  Rio de Janeiro    Advogada

# %%
# Para remover duplicatas em colunas específicas, use subset.
df_duplicada.drop_duplicates(subset=['nome'])
# Out:
#      nome  idade          cidade   profissão
# 0    João     25       São Paulo  Engenheiro
# 1   Maria     30  Rio de Janeiro    Advogada
# 2   Lucas     28  Belo Horizonte   Professor
# 3     Ana     35        Salvador      Médica
# 4  Carlos     40        Brasília  Empresário

# %% [markdown]
# # **Estatísticas descritivas**

# %%
# Exemplo
df_descritiva = pd.DataFrame({'ID': [1, 2, 3, 4, 5],
                            'Idade': [35, 28, 42, 31, 39],
                            'Altura': [1.75, 1.68, 1.80, 1.60, 1.70],
                            'Peso': [70, 55, 80, 60, 75],
                            'Salário': [5000, 6500, 8700, 4500, 5500],
                            'Pontuação': [85, 92, 78, 88, 90]
                            })

df_descritiva
# Out:
#    ID  Idade  Altura  Peso  Salário  Pontuação
# 0   1     35    1.75    70     5000         85
# 1   2     28    1.68    55     6500         92
# 2   3     42    1.80    80     8700         78
# 3   4     31    1.60    60     4500         88
# 4   5     39    1.70    75     5500         90

# %%
# Método de estatística descritiva do exemplo
df_descritiva.describe()
# Out:
#              ID      Idade    Altura       Peso      Salário  Pontuação
# count  5.000000   5.000000  5.000000   5.000000     5.000000   5.000000
# mean   3.000000  35.000000  1.706000  68.000000  6040.000000  86.600000
# std    1.581139   5.700877  0.075366  10.368221  1660.722734   5.458938
# min    1.000000  28.000000  1.600000  55.000000  4500.000000  78.000000
# 25%    2.000000  31.000000  1.680000  60.000000  5000.000000  85.000000
# 50%    3.000000  35.000000  1.700000  70.000000  5500.000000  88.000000
# 75%    4.000000  39.000000  1.750000  75.000000  6500.000000  90.000000
# max    5.000000  42.000000  1.800000  80.000000  8700.000000  92.000000

# %%
# Boxplot via Pandas do exemplo
df_descritiva.plot.box(column="Salário", figsize=(7, 5))
plt.show()

# %%
# Método de estatística descritiva - CENIPA
df.describe()
